# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .section-card h1 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 2.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 1.25rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .container > .card:last-child {
#     margin-bottom: 2rem;
#   }
#   .card.blue {
#     border-left-color: #29b6f6;
#   }
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   .image-card img {
#     max-width: 50vw;
#     height: auto;
#     display: block;
#     margin: 10px auto;
#     border-radius: 5px;
#   }
#   h1 {
#     width: 100%;
#     text-align: center;
#     color: #ffffff;
#     font-size: 2.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1rem;
#     }
#     .container > .card:last-child {
#       margin-bottom: 1.5rem;
#     }
#     .section-card h1 {
#       font-size: 2rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#     h1 {
#       font-size: 2rem;
#     }
#   }
# </style>
#
# <div class="section-card">
# <h1>Variables</h1>
# </div>
#
# <div class="section-card">
#   <div class="container">
#     <div class="card image-card green">
#       <h3>Overview</h3>
#       <img src="../images/variables.webp" alt="Variables">
#     </div>
#     <div class="card blue">
#       <h3>Explanation</h3>
#       <p>In our last lesson, we explored basic data types in Python, like simple values. For example:</p>
#     </div>
#   </div>
# </div>

# %%
5.3
# Out:
# 5.3

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #ffa726;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   ul {
#     padding-left: 1.25rem;
#     margin-bottom: 0.75rem;
#   }
#   li {
#     margin-bottom: 0.5rem;
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p, li {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <h3>Explanation</h3>
#       <p>The value <code>5.3</code> is static. For larger programs, we need values that can change.</p>
#       <p>In this lesson, we cover:</p>
#       <ul>
#         <li><strong>Objects</strong>: Containers for any data type.</li>
#         <li><strong>Variables</strong>: Labels for accessing data in objects.</li>
#       </ul>
#       <p>You'll learn to use variables to manage data in Python. Let's start!</p>
#     </div>
# </div>

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   ul {
#     list-style-type: none;
#     padding-left: 0;
#     margin-bottom: 0.75rem;
#   }
#   ul li {
#     margin-bottom: 0.5rem;
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   ul li a {
#     color: #29b6f6;
#     text-decoration: none;
#     transition: color 0.3s ease;
#   }
#   ul li a:hover {
#     color: #66bb6a;
#     text-decoration: underline;
#   }
#   ul ul {
#     padding-left: 1.5rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     ul li {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc0_">
#   <h2>Table of Contents</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Contents</h3>
#       <ul>
#         <li><a href="#toc1_">Variable Assignment</a></li>
#         <li><a href="#toc2_">Variable Types in Python</a></li>
#         <li><a href="#toc3_">Variable Names</a>
#           <ul>
#             <li><a href="#toc3_1_">PEP 8</a></li>
#           </ul>
#         </li>
#         <li><a href="#toc4_">Reserved Words</a></li>
#         <li><a href="#toc5_">Constants</a>
#           <ul>
#             <li><a href="#toc5_1_">Naming Convention</a></li>
#           </ul>
#         </li>
#         <li><a href="#toc6_">Conclusion</a></li>
#         <li><a href="#toc7_">Practice Exercises</a></li>
#       </ul>
#     </div>
# </div>

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc1_">
#   <h2>Variable Assignment</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>In Python, a variable is a label for an object. You assign a value using <code>=</code> without prior declaration. For example:</p>
#     </div>
# </div>

# %%
n = 300

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #29b6f6;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <h3>Explanation</h3>
#       <p>This assigns 300 to <code>n</code>. You can use <code>n</code> in expressions, and Python uses its value:</p>
#     </div>
# </div>

# %%
n
# Out:
# 300

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #ffa726;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <h3>Explanation</h3>
#       <p>Variables are dynamic. Change <code>n</code>'s value, and Python uses the new value:</p>
#     </div>
# </div>

# %%
n = 1000

# %%
n

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #ba68c8;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <h3>Explanation</h3>
#       <p>Python supports chained assignment to set multiple variables at once:</p>
#     </div>
# </div>

# %%
a = b = c = 300
print(a, b, c)

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc2_">
#   <h2>Variable Types</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>Python variables don't have fixed types. The type is tied to the object they reference. For example:</p>
#     </div>
# </div>

# %%
var = 23.5
print(type(var))

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #29b6f6;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <h3>Explanation</h3>
#       <p>Here, <code>var</code> holds 23.5, a <code>float</code>. <code>type(var)</code> shows <code>&lt;class 'float'&gt;</code>. You can reassign <code>var</code>:</p>
#     </div>
# </div>

# %%
var = 10
print(type(var))

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #ffa726;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <h3>Explanation</h3>
#       <p>Now <code>var</code> is an <code>int</code>. Operations apply to the referenced object:</p>
#     </div>
# </div>

# %%
coffee = "black"
print(coffee.upper())

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #ba68c8;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <h3>Explanation</h3>
#       <p><code>upper()</code> acts on the string object <code>coffee</code> references. Python's dynamic typing allows variables to change types freely.</p>
#     </div>
# </div>

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc3_">
#   <h2>Variable Names</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>Variable names should be descriptive, using letters, numbers, and underscores, but not starting with numbers (e.g., <code>counter_1</code> is valid, <code>1_counter</code> is not). Use snake_case (e.g., <code>word_counter</code>) and avoid single letters except for loops. Names are case-sensitive, and reserved keywords are off-limits.</p>
#     </div>
# </div>

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc3_1_">
#   <h2>PEP 8</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>PEP 8 provides guidelines for readable Python code, covering naming, layout, and whitespace. Following it ensures consistency.</p>
#     </div>
# </div>

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc4_">
#   <h2>Reserved Words</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>Python's reserved keywords (e.g., <code>class</code>, <code>for</code>, <code>while</code>) cannot be used as variable names, as this causes syntax errors.</p>
#     </div>
# </div>

# %%
help("keywords")

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#     align-items: center;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin: 0 auto 1.5rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc5_">
#   <h2>Constants</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>Constants are values meant to stay unchanged, named in uppercase with underscores (e.g., <code>MAX_VALUE</code>). Python doesn't enforce immutability, but the convention signals intent.</p>
#     </div>
# </div>

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin-bottom: 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#     margin: 0 auto 2.5rem;
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 1.5rem auto;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin-bottom: 0.75rem;
#       margin-bottom: 0.75rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc6_">
#   <h2>Variables in Python</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>Variables are used to store data in a program. In Python, variables are created when you assign a value to them.</p>
#       <p>For example, if you want to store the number 5 in a variable called <code>x</code>, you can do:</p>
#       <pre><code>x = 5</code></pre>
#       <p>Here, <code>x</code> is a variable that stores the value 5.</p>
#     </div>
#   </div>
# </div>

# %%
x = 5

# %%
x

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#     margin: 0 auto 2.5rem;
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 1.25rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin-bottom: 0.75rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc5_1_">
#   <h2>Naming Convention</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>Constants in Python are named in uppercase with underscores separating words, like <code>MAX_VALUE</code> or <code>PI</code>.</p>
#       <p>This convention indicates that the value should not be modified, even though Python doesn't prevent changes.</p>
#     </div>
#   </div>
# </div>

# %%
PI = 3.14159
MAX_SIZE = 100

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#     margin: 0 auto 2.5rem;
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin-bottom: 0.75rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc6_">
#   <h2>Conclusion</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>In this tutorial, we delved deep into the world of Python variables. We learned about their dynamic nature, how to name them appropriately, the significance of reserved keywords, and the convention for defining constants.</p>
#       <p>Python's flexibility with variables is one of its strengths, allowing developers to write code more intuitively and without excessive constraints. However, with this flexibility comes the responsibility to use meaningful names and adhere to conventions, ensuring that the code remains readable and maintainable.</p>
#       <p>As you continue your Python journey, always remember the importance of clear and consistent code. It not only benefits others who might read your code but also your future self. Happy coding!</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#     margin: 0 auto 2.5rem;
#   }
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#   }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     border-left: 4px solid #66bb6a;
#     width: min(1000px, 90vw);
#     margin: 0 auto 2rem;
#   }
#   .card:hover {transform: translateY(-6px);box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);}
#   .card {transition: transform 0.3s ease, box-shadow 0.3s ease;}
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#   code {
#     background-color: #2e2e2e;
#     color: #f8f8f2;
#     padding: 2px 4px;
#     border-radius: 4px;
#     font-family: 'Courier New', monospace;
#   }
#   ol {
#     padding-left: 1.25rem;
#     margin-bottom: 0.75rem;
#   }
#   li {
#     margin-bottom: 0.5rem;
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#   }
#   ul {
#     padding-left: 1.25rem;
#     margin-bottom: 0.75rem;
#   }
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#     .card {
#       width: 100%;
#       padding: 1rem;
#       margin-bottom: 0.75rem;
#     }
#     .card h3 {
#       font-size: 1.2rem;
#     }
#     p, li {
#       font-size: 0.9rem;
#     }
#   }
# </style>
# <div class="section-card" id="toc7_">
#   <h2>Practice Exercises</h2>
#   <div class="container">
#     <div class="card">
#       <h3>Overview</h3>
#       <p>Here are some exercises to help you practice what you've learned about variables, constants, and reserved keywords in Python:</p>
#       <ol>
#         <li><strong>Simple Assignment</strong>
#           <ul>
#             <li>Create a variable named <code>fruit</code> and assign it the value "apple".</li>
#             <li>Print the value of <code>fruit</code>.</li>
#             <li>Change the value of <code>fruit</code> to "banana" and print it again.</li>
#           </ul>
#         </li>
#         <li><strong>Using Constants</strong>
#           <ul>
#             <li>Make a constant named <code>MAX_SCORE</code> and set its value to 100.</li>
#             <li>Try to change the value of <code>MAX_SCORE</code> to 90 and see what happens. Can you change it? Why?</li>
#           </ul>
#         </li>
#         <li><strong>Variable Names</strong>
#           <ul>
#             <li>Create three variables: <code>myAge</code>, <code>my_name</code>, and <code>MyHeight</code>.</li>
#             <li>Assign any values to these variables and print them.</li>
#           </ul>
#         </li>
#         <li><strong>Reserved Keywords</strong>
#           <ul>
#             <li>Try to create a variable with the name <code>while</code>. What happens?</li>
#             <li>Rename the variable to something that's not a reserved keyword and print its value.</li>
#           </ul>
#         </li>
#         <li><strong>Multiple Assignments</strong>
#           <ul>
#             <li>Assign values to three variables <code>x</code>, <code>y</code>, and <code>z</code> in a single line.</li>
#             <li>Print the values of <code>x</code>, <code>y</code>, and <code>z</code>.</li>
#           </ul>
#         </li>
#       </ol>
#     </div>
#   </div>
# </div>

# %%
# Your code for Practice Exercise 1 here

# %%
# Your code for Practice Exercise 2 here

# %%
# Your code for Practice Exercise 3 here

# %%
# Your code for Practice Exercise 4 here

# %%
# Your code for Practice Exercise 5 here
