# %% [markdown]
# <style>
#     * {
#       box-sizing: border-box;
#     }
#     .section-card {
#       background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#       border-radius: 15px;
#       padding: 2rem;
#       margin: 0 auto 2.5rem;
#       box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#       width: 100%;
#       max-width: min(1200px, 95vw);
#     }
#     .section-card h1, .section-card h2 {
#       text-align: center;
#       color: #ffffff;
#       margin-bottom: 1.5rem;
#       font-family: 'Poppins', sans-serif;
#       letter-spacing: 1px;
#     }
#     .section-card h1 {
#       font-size: 2.8rem;
#     }
#     .section-card h2 {
#       font-size: 1.8rem;
#     }
#     .container {
#       display: flex;
#       flex-direction: column;
#       gap: 1.25rem;
#       align-items: center;
#     }
#     .card {
#       background: linear-gradient(145deg, #24243e, #1e1e3a);
#       border-radius: 12px;
#       padding: 1.5rem;
#       box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#       border-left: 4px solid transparent;
#       width: min(1000px, 90vw);
#       margin: 0 auto 1.25rem;
#       transition: transform 0.3s ease, box-shadow 0.3s ease;
#     }
#     .card:hover {
#       transform: translateY(-6px);
#       box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);
#     }
#     .container > .card:last-child {
#       margin-bottom: 2rem;
#     }
#     .card h3 {
#       color: #ffffff;
#       font-size: 1.3rem;
#       margin-bottom: 0.75rem;
#       font-weight: bold;
#       font-family: 'Segoe UI', sans-serif;
#     }
#     p, li {
#       color: #dcdcdc;
#       font-size: 0.95rem;
#       line-height: 1.5;
#       font-family: 'Segoe UI', sans-serif;
#     }
#     p {
#       margin-bottom: 0.75rem;
#     }
#     ul, ol {
#       padding-left: 1.25rem;
#       margin-bottom: 0.75rem;
#     }
#     li {
#       margin-bottom: 0.5rem;
#     }
#     .card.green { border-left-color: #66bb6a; }
#     .card.blue { border-left-color: #29b6f6; }
#     .card.orange { border-left-color: #ffa726; }
#     .card.purple { border-left-color: #ba68c8; }
#     .card.red { border-left-color: #ef5350; }
#     .toc-card ul {
#       list-style-type: none;
#       padding-left: 0;
#     }
#     .note {
#     background-color: #fdd835;
#     color: #000;
#     padding: 1rem;
#     border-radius: 6px;
#     margin-top: 1.25rem;
#     font-style: italic;
#     font-size: 0.95rem;
#     font-family: 'Segoe UI', sans-serif;
#     width: min(900px, 90vw);
#     margin: 1.25rem auto 0;
#   }
#     .image-card img {
#     max-width: 40vw;
#     height: auto;
#     display: block;
#     margin: 10px auto;
#     border-radius: 5px;
#   }
#     .toc-card ul li a {
#       color: #29b6f6;
#       text-decoration: none;
#       transition: color 0.3s ease;
#     }
#     .toc-card ul li a:hover {
#       color: #66bb6a;
#       text-decoration: underline;
#     }
#     .toc-card ul ul {
#       padding-left: 1.5rem;
#     }
#     @media (max-width: 768px) {
#       .section-card {
#         padding: 1.25rem;
#       }
#       .card {
#         width: 100%;
#         padding: 1rem;
#         margin: 0 auto 1rem;
#       }
#       .container > .card:last-child {
#         margin-bottom: 0;
#       }
#       .section-card h1 { font-size: 2rem; }
#       .section-card h2 { font-size: 1.4rem; }
#       .card h3 { font-size: 1.2rem; }
#       p, li { font-size: 0.9rem; }
#       @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { width: 100%; padding: 1rem; margin: 0 auto 1rem; } .container > .card:last-child { margin-bottom: 1.5rem; } .container > .note:last-child { margin-bottom: 1.5rem; } .section-card h2 { font-size: 1.4rem; } p { font-size: 0.9rem; } .note { width: 100%; } }
#   @media (max-width: 480px) { h1 { font-size: 1.8rem; } .section-card h2 { font-size: 1.2rem; } .card { padding: 0.75rem; } .note { padding: 0.75rem; } p, li { font-size: 0.85rem; } }
#     }
# </style>
#
# <div class="section-card">
#   <h1>Welcome to the Python Programming Course</h1>
# </div>
# <div class="section-card">
#   <h2>A short introduction — what this course is and who it's for</h2>
#   <div class="container">
#     <!-- Hero image (from Unsplash, dynamic by query) -->
#     <div class="card image-card blue" style="text-align:center;">
#       <h3>Hi! Welcome 👋</h3>
#       <p>Hello — I'm excited you're here. This course is designed to teach you Python from the ground up in short, practical lessons. We'll balance explanation with hands-on examples so you can follow along on your own machine.</p>
#       <img src="https://www.mygreatlearning.com/blog/wp-content/uploads/2019/08/python-libraries-2.jpg" alt="Python code on laptop">
#     </div>
#     <div class="card orange">
#       <h3>Why learning Python matters?</h3>
#       <ul>
#         <li>Python is one of the easiest and most enjoyable programming languages to learn.</li>
#         <li>It helps you turn your ideas into real, working programs quickly.</li>
#         <li>It’s a tool that saves time and boosts productivity.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>Who is this course for?</h3>
#       <ul>
#         <li>Beginners who want to start programming.</li>
#         <li>Students who need Python for university projects.</li>
#         <li>Developers from other languages transitioning to Python.</li>
#         <li>Anyone interested in starting paths like web development, data analysis, automation, or AI.</li>
#         <img style="width: 40vw; height: auto;display: block; margin: 10px auto;border-radius: 5px;" src="../images/who_is_this_course_for.jpg" alt="who is this course for?">
#       </ul>
#     </div>
#     <div class="card purple">
#       <h3>Teaching method</h3>
#       <ul>
#         <li>Each lesson is presented as a clean and interactive Jupyter Notebook.</li>
#         <li>Concepts are explained through real examples and simple demonstrations</li>
#         <li>Exercises at the end of each section help reinforce what you’ve learned.</li>
#         <li>The course follows a clear, step-by-step progression.</li>
#       </ul>
#       <div class="note">
#       <strong>Tip:</strong> open each lesson folder in VS Code and try the examples as you watch.</p>
#       </div>
#     </div>
#     <div class="card blue">
#       <h3>Where to access the files?</h3>
#       <p>
#       All notebooks and course materials are available on GitHub:
#       <br>
#       <a href="https://github.com/MAA5524/Python-Course">GitHub Repository<a>
#       </p>
#     </div>
#     <div class="card red">
#       <h3>How to use these notebook?</h3>
#       <ol>
#         <li>Read the short sections and run code cells if present.</li>
#         <li>Try the exercises at the end of each lesson folder.</li>
#         <li>At the end of the course you'll build a small project that uses what you've learned.</li>
#       </ol>
#     </div>
#     <div>
#       <!-- Button to open the next notebook -->
#       <p style="text-align:center; margin-top:1rem;">
#         <a href="01 Introduction to Python Programming.ipynb" target="_blank" style="
#             display:inline-block;
#             background-color:#29b6f6;
#             color:white;
#             padding:0.6rem 1.2rem;
#             border-radius:8px;
#             text-decoration:none;
#             font-weight:bold;
#             transition: background-color 0.3s;
#         " onmouseover="this.style.backgroundColor='#66bb6a'" onmouseout="this.style.backgroundColor='#29b6f6'">
#           Go to Lesson 01
#         </a>
#       </p>
#     </div>
#   </div>
# </div>
