# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin-bottom: 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#     margin: 0 auto 2.5rem;
#   }
#
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#   }
#
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-left: 4px solid transparent;
#     width: min(1000px, 90vw);
#     margin: 0 auto;
#   }
#
#   .card:hover {
#     transform: translateY(-6px);
#     box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);
#   }
#
#   .image-card img {
#     max-width: 100%;
#     height: auto;
#     display: block;
#   }
#
#   h1 {
#     width: 100%;
#     text-align: center;
#     color: #ffffff;
#     font-size: 2.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#
#   ul {
#     list-style-type:none;
#     padding-left: 1.25rem;
#     margin-bottom: 0.75rem;
#
#   }
#
#   li {
#     margin-bottom: 0.5rem;
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#   }
#
#   .note {
#     background-color: #fdd835;
#     color: #000;
#     padding: 1rem;
#     border-radius: 6px;
#     margin-top: 1.25rem;
#     font-style: italic;
#     font-size: 0.95rem;
#     font-family: 'Segoe UI', sans-serif;
#     width: min(1000px, 90vw);
#     margin: 1.25rem auto 0;
#   }
#
#   .card.green {
#     border-left-color: #66bb6a;
#   }
#
#   .card.blue {
#     border-left-color: #29b6f6;
#   }
#
#   .card.orange {
#     border-left-color: #ffa726;
#   }
#
#   .card.purple {
#     border-left-color: #ba68c8;
#   }
#
#   .card.red {
#     border-left-color: #ef5350;
#   }
#
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#
#     .card {
#       width: 100%;
#       padding: 1rem;
#     }
#
#     .note {
#       width: 100%;
#     }
#
#     h1 {
#       font-size: 2rem;
#     }
#
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#
#     .card h3 {
#       font-size: 1.2rem;
#     }
#
#     p, li {
#       font-size: 0.9rem;
#     }
#   }
#
#   @media (max-width: 480px) {
#     h1 {
#       font-size: 1.8rem;
#     }
#
#     .section-card h2 {
#       font-size: 1.2rem;
#     }
#
#     .card {
#       padding: 0.75rem;
#     }
#
#     .note {
#       padding: 0.75rem;
#     }
#
#     p, li {
#       font-size: 0.85rem;
#     }
#   }
# </style>
#
# <div class="section-card">
#   <h1>Introduction to Python Development Environment</h1>
# </div>
# <div class="section-card" id="toc0_">
#   <h2>Table of contents</h2>
#   <div class="container">
#     <div class="card blue toc-card">
#     <ul>
#         <li><a href="#toc1_">Python Development Environment</a>
#           <ul>
#             <li><a href="#toc1_1_">Definition</a></li>
#             <li><a href="#toc1_2_">Components</a></li>
#           </ul>
#         </li>
#         <li><a href="#toc2_">VS Code (Visual Studio Code)</a>
#           <ul>
#             <li><a href="#toc2_1_">Definition</a></li>
#             <li><a href="#toc2_2_">Features</a></li>
#           </ul>
#         </li>
#         <li><a href="#toc3_">Jupyter Notebook</a>
#           <ul>
#             <li><a href="#toc3_1_">Definition</a></li>
#             <li><a href="#toc3_2_">Use Cases</a></li>
#             <li><a href="#toc3_3_">Integration with VS Code</a></li>
#           </ul>
#         </li>
#         <li><a href="#toc4_">Conda</a>
#           <ul>
#             <li><a href="#toc4_1_">Definition</a></li>
#             <li><a href="#toc4_2_">Functionality</a></li>
#           </ul>
#         </li>
#         <li><a href="#toc5_">Benefits of Using VS Code, Jupyter Notebook, and Conda Together</a>
#           <ul>
#             <li><a href="#toc5_1_">Tool Integration</a></li>
#             <li><a href="#toc5_2_">Seamless Integration</a></li>
#             <li><a href="#toc5_2_">Enhanced Productivity</a></li>
#             <li><a href="#toc5_2_">Flexible Collaboration</a></li>
#             <li><a href="#toc5_2_">Scalability and Reproducibility</a></li>
#           </ul>
#         </li>
#       </ul>
#     </div>
#   </div>
# </div>
# <!-- Section 1: Python Development Environment -->
# <div class="section-card" id="toc1_">
#   <h2>Python Development Environment</h2>
#   <div class="container">
#     <div class="card image-card orange">
#       <h3>Overview</h3>
#       <img src="https://cdn.open-pr.com/V/c/Vc26705758_g.jpg" alt="Python Development Environment" style="max-width: 50vw; height: auto; display: block; margin: 10px auto; border-radius: 5px;">
#     </div>
#     <div class="card orange" id="toc1_1_">
#       <h3>Definition</h3>
#       <p>The Python development environment refers to the set of tools and software configurations required to write, run, debug, and manage Python code efficiently.</p>
#     </div>
#     <div class="card orange" id="toc1_2_">
#       <h3>Components</h3>
#       <p>It encompasses text editors or integrated development environments (IDEs), package managers, and other supporting tools that enhance the development workflow.</p>
#     </div>
#   </div>
# </div>
#
# <!-- Section 2: VS Code (Visual Studio Code) -->
# <div class="section-card" id="toc2_">
#   <h2>VS Code (Visual Studio Code)</h2>
#   <div class="container">
#     <div class="card image-card purple">
#       <h3>VS Code Interface</h3>
#       <img src="../images/python-vscode.png" alt="VS Code Interface" style="max-width: 50vw; height: auto; display: block; margin: 10px auto; border-radius: 5px;">
#     </div>
#     <div class="card purple" id="toc2_1_">
#       <h3>Definition</h3>
#       <p>VS Code is a lightweight and highly customizable code editor developed by Microsoft.</p>
#     </div>
#     <div class="card purple" id="toc2_2_">
#       <h3>Features</h3>
#       <p>It offers robust features for Python development, including syntax highlighting, code completion, debugging support, version control integration, and extensibility through a wide range of extensions.</p>
#     </div>
#   </div>
# </div>
#
# <!-- Section 3: Jupyter Notebook -->
# <div class="section-card" id="toc3_">
#   <h2>Jupyter Notebook</h2>
#   <div class="container">
#     <div class="card image-card red">
#       <h3>Jupyter Interface</h3>
#       <img src="../images/jupyter-interface.png" alt="Jupyter Notebook Interface" style="max-width: 50vw; height: auto; display: block; margin: 10px auto; border-radius: 5px;">
#     </div>
#     <div class="card red" id="toc3_1_">
#       <h3>Definition</h3>
#       <p>Jupyter Notebook is an interactive computing environment that allows users to create and share documents containing live code, visualizations, explanatory text, and more.</p>
#     </div>
#     <div class="card red" id="toc3_2_">
#       <h3>Use Cases</h3>
#       <p>It is particularly useful for data analysis, exploratory programming, and documentation purposes.</p>
#     </div>
#     <div class="card red" id="toc3_3_">
#       <h3>Integration with VS Code</h3>
#       <p>The Jupyter Notebook extension enables seamless integration with VS Code, allowing you to create, edit, and run Jupyter notebooks directly within the editor with features like cell execution, interactive outputs, and markdown rendering.</p>
#     </div>
#     <div class="note">
#       <strong>Note:</strong> To enhance the functionality of VS Code for Jupyter Notebook development, utilize the Jupyter Notebook extension for a powerful tool in data analysis and prototyping.
#     </div>
#   </div>
# </div>
#
# <!-- Section 4: Conda -->
# <div class="section-card" id=""toc4_>
#   <h2>Conda</h2>
#   <div class="container">
#     <div class="card image-card green">
#       <h3>Conda Overview</h3>
#       <img src="../images/conda-python.jpg" alt="Conda Environment" style="max-width: 50vw; height: auto; display: block; margin: 10px auto; border-radius: 5px;">
#     </div>
#     <div class="card green" id=""toc4_1_>
#       <h3>Definition</h3>
#       <p>Conda is a popular package manager and environment management system for Python and other programming languages.</p>
#     </div>
#     <div class="card green" id=""toc4_2_>
#       <h3>Functionality</h3>
#       <p>It simplifies the process of installing, managing, and organizing packages and dependencies within isolated environments, ensuring reproducibility and avoiding conflicts between different projects.</p>
#     </div>
#   </div>
# </div>
#
# <!-- Section 5: Benefits of Using VS Code, Jupyter Notebook, and Conda Together -->
# <div class="section-card" id="toc5_">
#   <h2>Benefits of Using VS Code, Jupyter Notebook, and Conda Together</h2>
#   <div class="container">
#     <div class="card image-card blue">
#       <h3>Tool Integration</h3>
#       <img src="../images/python-vscode.png" alt="Tool Integration" style="max-width: 50vw; height: auto; display: block; margin: 10px auto; border-radius: 5px;">
#     </div>
#     <div class="card blue" id="toc5_1_">
#       <h3>Seamless Integration</h3>
#       <p>VS Code provides a powerful interface for editing Python code, Jupyter Notebook offers interactive development, and Conda manages packages in isolated environments for consistent setups.</p>
#     </div>
#     <div class="card blue" id="toc5_2_">
#       <h3>Enhanced Productivity</h3>
#       <p>VS Code’s features like code snippets, autocompletion, and debugging, combined with Jupyter’s interactive prototyping, boost developer productivity.</p>
#     </div>
#     <div class="card blue" id="toc5_3_">
#       <h3>Flexible Collaboration</h3>
#       <p>VS Code supports version control for collaboration, and Jupyter Notebook files can be shared easily for effective data analysis workflows.</p>
#     </div>
#     <div class="card blue" id="toc5_4_">
#       <h3>Scalability and Reproducibility</h3>
#       <p>Conda’s environment management ensures reproducibility across machines, simplifying deployment and scalability.</p>
#     </div>
#   </div>
# </div>
