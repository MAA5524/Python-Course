# %% [markdown]
# <style>
#   * {
#     box-sizing: border-box;
#   }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin-bottom: 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: min(1200px, 95vw);
#     margin: 0 auto 2.5rem;
#   }
#
#   .section-card h2 {
#     text-align: center;
#     color: #ffffff;
#     font-size: 1.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container {
#     display: flex;
#     flex-direction: column;
#     gap: 1.25rem;
#   }
#
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px;
#     padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#     transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-left: 4px solid transparent;
#     width: min(1000px, 90vw);
#     margin: 0 auto;
#   }
#
#   .card:hover {
#     transform: translateY(-6px);
#     box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);
#   }
#
#   .image-card img {
#     max-width: 100%;
#     height: auto;
#     display: block;
#   }
#
#   h1 {
#     width: 100%;
#     text-align: center;
#     color: #ffffff;
#     font-size: 2.8rem;
#     margin-bottom: 1.5rem;
#     font-family: 'Poppins', sans-serif;
#     letter-spacing: 1px;
#   }
#
#   .card h3 {
#     color: #ffffff;
#     font-size: 1.3rem;
#     margin-bottom: 0.75rem;
#     font-weight: bold;
#     font-family: 'Segoe UI', sans-serif;
#   }
#
#   p {
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#     margin-bottom: 0.75rem;
#   }
#
#   ul {
#     padding-left: 1.25rem;
#     margin-bottom: 0.75rem;
#   }
#
#   li {
#     margin-bottom: 0.5rem;
#     color: #dcdcdc;
#     font-size: 0.95rem;
#     line-height: 1.5;
#     font-family: 'Segoe UI', sans-serif;
#   }
#
#   .note {
#     background-color: #fdd835;
#     color: #000;
#     padding: 1rem;
#     border-radius: 6px;
#     margin-top: 1.25rem;
#     font-style: italic;
#     font-size: 0.95rem;
#     font-family: 'Segoe UI', sans-serif;
#     width: min(1000px, 90vw);
#     margin: 1.25rem auto 0;
#   }
#
#   .card.green {
#     border-left-color: #66bb6a;
#   }
#
#   .card.blue {
#     border-left-color: #29b6f6;
#   }
#
#   .card.orange {
#     border-left-color: #ffa726;
#   }
#
#   .card.purple {
#     border-left-color: #ba68c8;
#   }
#
#   .card.red {
#     border-left-color: #ef5350;
#   }
#
#   .toc-card ul {
#     list-style-type: none;
#     padding-left: 0;
#   }
#
#   .toc-card ul li {
#     margin-bottom: 0.5rem;
#   }
#
#   .toc-card ul li a {
#     color: #29b6f6;
#     text-decoration: none;
#     transition: color 0.3s ease;
#   }
#
#   .toc-card ul li a:hover {
#     color: #66bb6a;
#     text-decoration: underline;
#   }
#
#   .toc-card ul ul {
#     padding-left: 1.5rem;
#   }
#
#   @media (max-width: 768px) {
#     .section-card {
#       padding: 1.25rem;
#       max-width: 95vw;
#     }
#
#     .card {
#       width: 100%;
#       padding: 1rem;
#     }
#
#     .note {
#       width: 100%;
#     }
#
#     h1 {
#       font-size: 2rem;
#     }
#
#     .section-card h2 {
#       font-size: 1.4rem;
#     }
#
#     .card h3 {
#       font-size: 1.2rem;
#     }
#
#     p, li {
#       font-size: 0.9rem;
#     }
#   }
#
#   @media (max-width: 480px) {
#     h1 {
#       font-size: 1.8rem;
#     }
#
#     .section-card h2 {
#       font-size: 1.2rem;
#     }
#
#     .card {
#       padding: 0.75rem;
#     }
#
#     .note {
#       padding: 0.75rem;
#     }
#
#     p, li {
#       font-size: 0.85rem;
#     }
#   }
# </style>
#
# <div class="section-card">
#   <h1>Getting Started with VS Code</h1>
# </div>
#
# <div class="section-card" id="toc0_">
#   <h2>Table of Contents</h2>
#   <div class="container">
#     <div class="card toc-card blue">
#       <h3>Contents</h3>
#       <ul>
#         <li><a href="#toc1_">Opening Projects</a></li>
#         <li><a href="#toc2_">Interface Tour</a></li>
#         <li><a href="#toc3_">Core Extensions (Python & Jupyter)</a></li>
#         <li><a href="#toc4_">Basic Editing Shortcuts</a></li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc1_">
#   <h2>Opening Projects & Files</h2>
#   <div class="container">
#     <div class="card orange">
#       <h3>Best Ways to Start</h3>
#       <ul>
#         <li><strong>Terminal (Recommended):</strong> Navigate to your folder and type <code>code .</code></li>
#         <li><strong>GUI:</strong> <code>File -> Open Folder</code> (Ctrl/Cmd + K + O).</li>
#         <li><strong>Context Menu:</strong> Right-click any folder and select <strong>"Open with Code"</strong>.</li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc2_">
#   <h2>Interface Overview</h2>
#   <div class="container">
#     <div class="card purple">
#       <ul>
#         <li><strong>Editor:</strong> Your main coding area.</li>
#         <li><strong>Sidebar:</strong> Explorer (Files), Search, and Extensions.</li>
#         <li><strong>Command Palette:</strong> The heart of VS Code (<code>Ctrl/Cmd + Shift + P</code>).</li>
#         <li><strong>Status Bar:</strong> Bottom bar showing Python version and encoding.</li>
#       </ul>
#       <img src="../images/vscode-interface.png" alt="Interface" style="max-width: 65%; display: block; margin: 15px auto; border-radius: 8px;">
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc3_">
#   <h2>Essential Extensions</h2>
#   <div class="container">
#     <div class="card green">
#       <h3>Python Extension</h3>
#       <p>Adds <strong>IntelliSense</strong> (Autofill), <strong>Linting</strong> (Error checking), and <strong>Formatting</strong> (PEP 8).</p>
#       <img src="../images/vscode-python-ext.png" alt="Python Extension" style="max-width: 50vw; height: auto; display: block; margin: 10px auto; border-radius: 5px;">
#     </div>
#     <div class="card green">
#       <h3>Jupyter Extension</h3>
#       <p>Allows creating <code>.ipynb</code> files, managing <strong>Kernels</strong>, and interactive data visualization.</p>
#       <img src="../images/vscode-jupyter-ext.png" alt="Jupyter Extension" style="max-width: 50vw; height: auto; display: block; margin: 10px auto; border-radius: 5px;">
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc4_">
#   <h2>Must-Know Shortcuts</h2>
#   <div class="container">
#     <div class="card red">
#       <table style="width:100%; color:#dcdcdc; border-collapse: collapse;">
#         <tr><td style="padding: 5px;"><strong>Save:</strong></td><td><code>Ctrl/Cmd + S</code></td></tr>
#         <tr><td style="padding: 5px;"><strong>Quick Open File:</strong></td><td><code>Ctrl/Cmd + P</code></td></tr>
#         <tr><td style="padding: 5px;"><strong>Toggle Sidebar:</strong></td><td><code>Ctrl/Cmd + B</code></td></tr>
#         <tr><td style="padding: 5px;"><strong>Terminal:</strong></td><td><code>Ctrl + `</code></td></tr>
#       </ul>
#     </div>
#   </div>
# </div>
