# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   /* Global Settings */
#   * { box-sizing: border-box; }
#
#   /* Section Card Style */
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px;
#     padding: 2rem;
#     margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#     width: 100%;
#     max-width: 95vw;
#     direction: rtl; /* راست‌چین کردن محتوا */
#     font-family: 'Vazirmatn', sans-serif;
#   }
#
#   /* Typography */
#   .section-card h1 {
#     text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700;
#   }
#   .section-card h2 {
#     text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700;
#   }
#   .card h3 {
#     color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700;
#     border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem;
#   }
#   p, li {
#     color: #dcdcdc; font-size: 1rem; line-height: 1.8;
#   }
#   p { margin-bottom: 0.75rem; }
#   ul { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   li { margin-bottom: 0.5rem; }
#
#   /* Inner Cards & Container */
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent; /* حاشیه رنگی به سمت راست */
#     width: 90vw; margin: 0 auto;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   /* Image Styling */
#   .image-card img, .card img {
#     max-width: 50vw; height: auto; display: block; margin: 15px auto; border-radius: 8px;
#   }
#
#   /* Note Box */
#   .note {
#     background-color: #fdd835; color: #000; padding: 1rem; border-radius: 6px;
#     margin: 1.25rem auto 0; font-size: 0.95rem; font-weight: 500;
#     width: 90vw;
#   }
#
#   /* Color Theme (Right Borders) */
#   .green { border-right-color: #66bb6a; }
#   .blue { border-right-color: #29b6f6; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   /* Table of Contents */
#   .toc-card ul { list-style-type: none; padding-right: 1rem; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; font-weight: 500; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#
#   /* Responsive Design */
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; max-width: 95vw; }
#     .card { width: 100%; padding: 1rem; }
#     .note { width: 100%; }
#     .section-card h1 { font-size: 2rem; }
#     .section-card h2 { font-size: 1.4rem; }
#     .card h3 { font-size: 1.2rem; }
#     p, li { font-size: 0.95rem; }
#     .image-card img, .card img { max-width: 85%; }
#   }
# </style>
#
# <!-- HEADER -->
# <div class="section-card">
#   <h1>آشنایی با محیط توسعه پایتون 🛠️</h1>
# </div>
#
# <!-- TOC -->
# <div class="section-card" id="toc0_">
#   <h2>فهرست مطالب</h2>
#   <div class="container">
#     <div class="card blue toc-card">
#     <h3>دسترسی سریع</h3>
#       <ul>
#         <li><a href="#toc1_">۱. محیط توسعه چیست؟</a></li>
#         <li><a href="#toc2_">۲. VS Code (ویرایشگر کد)</a></li>
#         <li><a href="#toc3_">۳. ژوپیتر نوت‌بوک (آزمایشگاه تعاملی)</a></li>
#         <li><a href="#toc4_">۴. Conda و venv (مدیریت محیط‌ها)</a></li>
#         <li><a href="#toc5_">۵. چرا از این ترکیب استفاده می‌کنیم؟</a></li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <!-- SECTION 1 -->
# <div class="section-card" id="toc1_">
#   <h2>۱. محیط توسعه پایتون (Environment)</h2>
#   <div class="container">
#     <div class="card orange">
#       <h3>این محیط دقیقاً چیست؟</h3>
#       <p>محیط توسعه در واقع «میز کار دیجیتال» شماست؛ مجموعه‌ای از ابزارها (ویرایشگرها، مفسرها و نرم‌افزارهای مدیریت پکیج) که با هم کار می‌کنند تا بتوانید کدهای پایتون را با بالاترین سرعت و دقت بنویسید، تست کنید و اجرا نمایید.</p>
#       <img src="../../images/IDES.png" alt="محیط توسعه">
#     </div>
#   </div>
# </div>
#
# <!-- SECTION 2 -->
# <div class="section-card" id="toc2_">
#   <h2>۲. ویرایشگر VS Code</h2>
#   <div class="container">
#     <div class="card purple">
#       <h3>«چاقوی سوئیسیِ» برنامه‌نویس‌ها</h3>
#       <p>یک ویرایشگر کد بسیار سبک اما فوق‌العاده قدرتمند از مایکروسافت. این ابزار به دلیل داشتن ویژگی‌های زیر، استاندارد فعلی صنعت برنامه‌نویسی است:</p>
#       <ul>
#         <li><strong>IntelliSense:</strong> تکمیل هوشمند کدها (به شما پیشنهاد می‌دهد خط بعدی چیست).</li>
#         <li><strong>افزونه‌ها (Extensions):</strong> هزاران پلاگین برای اضافه کردن امکانات پایتون و زیباسازی محیط.</li>
#         <li><strong>ترمینال داخلی:</strong> می‌توانید کدهایتان را بدون خارج شدن از ویرایشگر، اجرا کنید.</li>
#       </ul>
#       <img src="../../images/python-vscode.png" alt="VS Code">
#     </div>
#   </div>
# </div>
#
# <!-- SECTION 3 -->
# <div class="section-card" id="toc3_">
#   <h2>۳. ژوپیتر نوت‌بوک (Jupyter Notebook)</h2>
#   <div class="container">
#     <div class="card red">
#       <h3>آزمایشگاه تعاملی شما</h3>
#       <p>بهترین ابزار برای یادگیری برنامه‌نویسی و علم داده. ژوپیتر به شما اجازه می‌دهد <strong>کدهای قابل اجرا</strong>، <strong>متن‌های توضیحی</strong> و <strong>نمودارها</strong> را همه در یک فایل ترکیب کنید.</p>
#       <p>در این دوره، ما از «افزونه ژوپیتر در داخل VS Code» استفاده می‌کنیم تا از قدرت هر دو ابزار همزمان بهره‌مند شویم.</p>
#       <img src="../../images/jupyter-interface.png" alt="محیط ژوپیتر">
#     </div>
#     <div class="note">
#       <strong>💡 نکته مهم:</strong> ژوپیتر بهترین انتخاب برای تست سریع ایده‌ها (Prototyping) و یادگیری قدم‌به‌قدم است، چون خروجی هر بخش از کد را بلافاصله نشان می‌دهد.
#     </div>
#   </div>
# </div>
#
# <!-- SECTION 4 -->
# <div class="section-card" id="toc4_">
#   <h2>۴. مدیریت محیط‌ها (Environment Management)</h2>
#   <div class="container">
#     <div class="card green">
#       <h3>پروژه‌ها را ایزوله نگه دارید</h3>
#       <p>برای جلوگیری از تداخلِ کتابخانه‌ها بین پروژه‌های مختلف (مثلاً یک پروژه نسخه قدیمی پانداس را بخواهد و دیگری نسخه جدید)، از محیط‌های ایزوله استفاده می‌کنیم:</p>
#       <ul>
#         <li><strong>Conda:</strong> ابزاری بسیار قدرتمند برای علم داده و مدیریت پکیج‌های پیچیده و سنگین.</li>
#         <li><strong>venv:</strong> ابزار پیش‌فرض، سریع و سبکِ خود پایتون برای ساخت محیط مجازی.</li>
#       </ul>
#       <img src="../../images/venv_vs_conda.png" alt="مقایسه Conda و venv">
#     </div>
#   </div>
# </div>
#
# <!-- SECTION 5 -->
# <div class="section-card" id="toc5_">
#   <h2>۵. چرا از این ترکیبِ مدرن استفاده می‌کنیم؟</h2>
#   <div class="container">
#     <div class="card blue">
#       <ul>
#         <li>🚀 <strong>بهره‌وری (Productivity):</strong> دیباگ کردن و اجرای کدها در VS Code بسیار سریع است.</li>
#         <li>🛡️ <strong>پایداری (Consistency):</strong> ابزارهای Conda و venv تضمین می‌کنند که کد شما روی سیستم دوستانتان هم بدون خطا اجرا شود.</li>
#         <li>🧠 <strong>شفافیت (Clarity):</strong> ژوپیتر کمک می‌کند تا منطق‌های پیچیده برنامه‌نویسی را به راحتی توضیح دهید و خروجی را مصورسازی کنید.</li>
#       </ul>
#     </div>
#   </div>
# </div>
