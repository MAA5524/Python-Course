# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li, td, th { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; font-family: 'Vazirmatn', sans-serif; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   pre { background: #1a1a2e; padding: 1rem; border-radius: 8px; overflow-x: auto; direction: ltr; text-align: left; margin-top: 8px; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .image-card img, .card img { max-width: 60%; height: auto; display: block; margin: 15px auto; border-radius: 8px; }
#   .note { background-color: #fdd835; color: #000; padding: 1rem; border-radius: 6px; margin: 1.25rem auto 0; font-weight: 500; font-size: 0.95rem; width: 100%; }
#   .toc-card ul { list-style-type: none; padding-right: 1rem; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; font-weight: 500; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#   .toc-card ul ul { padding-right: 1.5rem; margin-top: 0.5rem; list-style-type: circle; }
#   .toc-card ul ul li a { color: #dcdcdc; font-weight: normal; }
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#   .pink { border-right-color: #f06292; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; max-width: 95vw; } .card { width: 100%; padding: 1rem; } h1 { font-size: 2rem; } .section-card h2 { font-size: 1.4rem; } .card h3 { font-size: 1.2rem; } .image-card img, .card img { max-width: 85vw; } }
# </style>
# <div class='section-card'>
#     <h1>مستندسازی توابع (Function Documentation) 📝</h1>
# </div>
# <div class='section-card'>
#     <div class='container'>
#         <div class='card green'>
#             <p>مستندسازی توابع برای داشتن کدی خوانا و قابل نگهداری، کاملاً ضروری است. در این درس یاد می‌گیریم که چطور هدف و نحوه استفاده از یک تابع را از طریق «داک‌استرینگ‌ها» (Docstrings) به دیگران منتقل کنیم (شامل توضیح رفتار، پارامترها، خروجی‌ها و مثال‌ها).</p>
#         </div>
#         <div class='card green'>
#             <p>مواردی که در این بخش بررسی می‌کنیم: اهمیت مستندسازی، سینتکس داک‌استرینگ، بهترین روش‌ها، دسترسی به داک‌استرینگ در کد، استایل‌های مختلف نوشتن داکیومنت و در نهایت راهنمای نوع داده (Type Hints).</p>
#         </div>
#     </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li, td, th { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; font-family: 'Vazirmatn', sans-serif; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .toc-card ul { list-style-type: none; padding-right: 1rem; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; font-weight: 500; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#   .toc-card ul ul { padding-right: 1.5rem; margin-top: 0.5rem; list-style-type: circle; }
#   .toc-card ul ul li a { color: #dcdcdc; font-weight: normal; }
#   .blue { border-right-color: #29b6f6; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; max-width: 95vw; } .card { width: 100%; padding: 1rem; } h1 { font-size: 2rem; } .section-card h2 { font-size: 1.4rem; } .card h3 { font-size: 1.2rem; } }
# </style>
# <div class="section-card">
#   <h2>فهرست مطالب</h2>
#   <div class="container">
#     <div class="card blue toc-card">
#     <h3>دسترسی سریع</h3>
#       <ul>
#         <li><a href="#toc1_">۱. اهمیت مستندسازی توابع</a></li>
#         <li><a href="#toc2_">۲. داک‌استرینگ‌ها (Docstrings): مفاهیم پایه</a></li>
#         <li><a href="#toc3_">۳. نوشتن داک‌استرینگ‌های حرفه‌ای و موثر</a></li>
#         <li><a href="#toc4_">۴. نحوه دسترسی و خواندن داک‌استرینگ‌ها</a></li>
#         <li><a href="#toc5_">۵. استایل‌های مختلف داک‌استرینگ</a>
#           <ul>
#             <li><a href="#toc5_1_">استایل گوگل (Google Style)</a></li>
#             <li><a href="#toc5_2_">استایل نام‌پای (NumPy/SciPy Style)</a></li>
#             <li><a href="#toc5_3_">استایل reStructuredText (reST)</a></li>
#             <li><a href="#toc5_4_">استایل Epytext</a></li>
#             <li><a href="#toc5_5_">چگونه یک استایل انتخاب کنیم؟</a></li>
#           </ul>
#         </li>
#         <li><a href="#toc6_">۶. راهنمای نوع داده (Type Hints)</a>
#           <ul>
#             <li><a href="#toc6_1_">سینتکس (Syntax)</a></li>
#             <li><a href="#toc6_2_">مزایا</a></li>
#             <li><a href="#toc6_3_">ترکیب Type Hints با داک‌استرینگ</a></li>
#           </ul>
#         </li>
#         <li><a href="#toc7_">۷. تمرین عملی</a></li>
#       </ul>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .orange { border-right-color: #ffa726; }
# </style>
# <div class='section-card' id='toc1_'>
# <h2>۱. اهمیت مستندسازی توابع</h2>
# <div class='container'>
# <div class='card orange'>
# <p>مستندسازی (Documentation) تضمین می‌کند که کدهای شما خوانا باشند، به راحتی نگهداری شوند و کار تیمی و دیباگ کردن را به شدت ساده‌تر می‌کند.</p>
# </div>
# <div class='card orange'>
# <ul>
# <li><strong>خوانایی (Readability):</strong> هدف تابع را به سرعت منتقل می‌کند و از سردرگمی جلوگیری می‌کند.</li>
# <li><strong>نگهداری (Maintenance):</strong> هنگام ایجاد تغییرات در آینده، به برنامه‌نویس یادآوری می‌کند که منطق اولیه چه بوده است.</li>
# <li><strong>آشناسازی (Onboarding):</strong> به برنامه‌نویسان جدید کمک می‌کند تا سریع‌تر با پروژه آشنا شوند.</li>
# <li><strong>همکاری (Collaboration):</strong> درک تیم را نسبت به ورودی‌ها و خروجی‌های توابع هماهنگ می‌کند.</li>
# <li><strong>دیباگ کردن (Debugging):</strong> با ارائه توضیحات، ردیابی خطاها را بسیار راحت‌تر می‌کند.</li>
# <li><strong>قابلیت استفاده مجدد (Reusability):</strong> باعث می‌شود دیگران با اطمینان بیشتری از توابع شما در پروژه‌هایشان استفاده کنند.</li>
# </ul>
# </div>
# </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .purple { border-right-color: #ba68c8; }
# </style>
# <div class='section-card' id='toc2_'>
# <h2>۲. داک‌استرینگ‌ها (Docstrings): مفاهیم پایه</h2>
# <div class='container'>
# <div class='card purple'>
# <p>داک‌استرینگ (Docstring) یک رشته متنی است که برای مستندسازی ماژول‌ها، کلاس‌ها، متدها یا توابع نوشته می‌شود. این متن باید در داخل سه کوتیشن (<code>"""</code>) قرار بگیرد.</p>
# <p>مکان قرارگیری آن <strong>دقیقاً در خط اولِ بعد از تعریف تابع</strong> است. پایتون به طور خودکار این متن را در ویژگی <code>__doc__</code> ذخیره می‌کند تا بعداً با دستور <code>help()</code> قابل خواندن باشد.</p>
# </div>
# </div>
# </div>

# %%
def my_function():
    """This is a docstring that describes what the my_function() does."""
    # Function body goes here

# %%
def greet(name):
    """
    Greets a person with a hello message.

    Args:
        name (str): The name of the person to greet.

    Returns:
        None
    """
    print(f"Hello, {name}!")

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .red { border-right-color: #ef5350; }
# </style>
# <div class='section-card' id='toc3_'>
# <h2>۳. نوشتن داک‌استرینگ‌های حرفه‌ای و موثر</h2>
# <div class='container'>
# <div class='card red'>
# <p>یک داک‌استرینگ حرفه‌ای معمولاً شامل این بخش‌هاست: یک توضیح کوتاه از عملکرد تابع، لیست پارامترها (نام، نوع داده و توضیح هرکدام)، خروجی تابع (نوع داده و توضیح)، مثال‌های کاربردی، خطاهایی که ممکن است رخ دهد (Raises) و یادداشت‌های اضافی.</p>
# </div>
# <div class='card red' id="toc3_1_">
# <h3>اهمیت استایل (Style)</h3>
# <p>برای اینکه کدهایتان استاندارد و منظم به نظر برسد، سعی کنید همیشه از یک فرمت ثابت (مثل استایل Google یا NumPy) استفاده کنید تا ابزارهای خودکار هم بتوانند به راحتی از کدهای شما فایل راهنما (Documentation) بسازند.</p>
# </div>
# </div>
# </div>

# %%
def calculate_area(radius):
    """
    Calculate the area of a circle given its radius.

    Args:
        radius (float): The radius of the circle.

    Returns:
        float: The area of the circle.

    Raises:
        ValueError: If the radius is negative.

    Examples:
        >>> calculate_area(5)
        78.53981633974483

    Note:
        The area is calculated using the formula pi * radius^2.
    """
    if radius < 0:
        raise ValueError("The radius cannot be negative.")
    return 3.141592653589793 * radius ** 2

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .green { border-right-color: #66bb6a; }
# </style>
# <div class='section-card' id="toc4_">
# <h2>۴. نحوه دسترسی و خواندن داک‌استرینگ‌ها</h2>
# <div class='container'>
# <div class='card green' id="toc4_1">
# <h3>استفاده از تابع <code>help()</code></h3>
# <p>تابع <code>help()</code> یک ابزار داخلی قدرتمند در پایتون است که با دریافت نام تابع، تمام اطلاعات نوشته شده در داک‌استرینگ آن را به صورت مرتب در خروجی نمایش می‌دهد.</p>
# </div>
# </div>
# </div>

# %%
def my_function():
    """This is a simple docstring."""
    pass

# %%
my_function.__doc__
# Out:
# 'این یک داک‌استرینگ ساده است.'

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .green { border-right-color: #66bb6a; }
# </style>
# <div class='section-card' id='toc4_2_'>
# <div class='container'>
# <div class='card green'>
# <h3>استفاده از ویژگی <code>.__doc__</code></h3>
# <p>هر تابع در پایتون یک صفت (Attribute) مخفی به نام <code>__doc__</code> دارد که دقیقاً همان متن داک‌استرینگ را در خود نگهداری می‌کند. می‌توانید آن را به صورت مستقیم پرینت بگیرید.</p>
# </div>
# </div>
# </div>

# %%
def calculate_area(radius):
    """
    مساحت یک دایره را بر اساس شعاع آن محاسبه می‌کند.

    Args:
        radius (float): شعاع دایره.

    Returns:
        float: مساحت محاسبه شده دایره.
    """
    return 3.141592653589793 * radius ** 2

# %%
# استفاده از help()
help(calculate_area)
# Out:
# Help on function calculate_area in module __main__:
#
# calculate_area(radius)
#     مساحت یک دایره را بر اساس شعاع آن محاسبه می‌کند.
#
#     Args:
#         radius (float): شعاع دایره.
#
#     Returns:
#         float: مساحت محاسبه شده دایره.

# %%
# استفاده از __doc__
print(calculate_area.__doc__)
# Out:
#     مساحت یک دایره را بر اساس شعاع آن محاسبه می‌کند.
#
#     Args:
#         radius (float): شعاع دایره.
#
#     Returns:
#         float: مساحت محاسبه شده دایره.

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .green { border-right-color: #66bb6a; }
# </style>
# <div class='section-card' id='toc4_3_'>
# <div class='container'>
# <div class='card green'>
# <h3>در محیط‌های تعاملی (Interactive Environments)</h3>
# <p>در ابزارهایی مثل IPython یا ژوپیتر نوت‌بوک، کافیست یک علامت سوال <code>?</code> به انتهای نام تابع اضافه کنید و کد را اجرا کنید تا داک‌استرینگ آن در یک پنجره شناور زیبا نمایش داده شود.</p>
# </div>
# </div>
# </div>

# %%
calculate_area?
# Out:
# Signature: calculate_area(radius)
# Docstring:
# مساحت یک دایره را بر اساس شعاع آن محاسبه می‌کند.
#
# Args:
#     radius (float): شعاع دایره.
#
# Returns:
#     float: مساحت محاسبه شده دایره.
# Type:      function

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .pink { border-right-color: rgb(239, 80, 157); }
# </style>
# <div class='section-card' id='toc5_'>
# <h2>۵. استایل‌های مختلف داک‌استرینگ</h2>
# <div class='container'>
# <div class='card pink' id="toc5_1_">
# <h3>استایل گوگل (Google Style)</h3>
# <p>در استایل گوگل از تو رفتگی‌ها (Indentation) برای جدا کردن بخش‌های مختلف استفاده می‌شود. این استایل بسیار خواناست و یادگیری آن برای برنامه‌نویسان بسیار ساده است.</p>
# </div>
# </div>
# </div>

# %%
def multiply(a: float, b: float) -> float:
    """
    دو عدد را در هم ضرب می‌کند.

    Args:
        a (float): عدد اول.
        b (float): عدد دوم.

    Returns:
        float: حاصل ضرب عدد a و b.
    """
    return a * b

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .pink { border-right-color: rgb(239, 80, 157); }
# </style>
# <div class='section-card' id='toc5_2_'>
# <div class='container'>
# <div class='card pink'>
# <h3>استایل نام‌پای (NumPy/SciPy Style)</h3>
# <p>این استایل بسیار ساختاریافته است و بیشتر در پروژه‌های علمی پایتون استفاده می‌شود. در این روش از خط‌چین‌ها (---) زیر عناوین استفاده می‌شود.</p>
# </div>
# </div>
# </div>

# %%
def function(arg1, arg2):
    """
    یک توضیح کلی از عملکرد تابع.

    Parameters
    ----------
    arg1 : int
        توضیحات مربوط به آرگومان اول.
    arg2 : str
        توضیحات مربوط به آرگومان دوم.

    Returns
    -------
    bool
        توضیحاتی درباره مقداری که بازگردانده می‌شود.
    """
    pass

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .pink { border-right-color: rgb(239, 80, 157); }
# </style>
# <div class='section-card' id='toc5_3_'>
# <div class='container'>
# <div class='card pink'>
# <h3>استایل reStructuredText (reST)</h3>
# <p>این فرمت، زبان نشانه‌گذاری استاندارد (Markup) برای مستندات پایتون است. با ابزاری به نام Sphinx به خوبی یکپارچه می‌شود تا صفحات راهنمای تحت وب و حرفه‌ای بسازد.</p>
# </div>
# </div>
# </div>

# %%
def multiply(a: float, b: float) -> float:
    """
    دو عدد را ضرب می‌کند.

    :param a: عدد اول.
    :type a: float
    :param b: عدد دوم.
    :type b: float
    :returns: حاصل ضرب a و b.
    :rtype: float
    """
    return a * b

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .pink { border-right-color: rgb(239, 80, 157); }
# </style>
# <div class='section-card' id='toc5_4_'>
# <div class='container'>
# <div class='card pink'>
# <h3>استایل Epytext</h3>
# <p>این فرمت بسیار شبیه به Javadoc (در زبان جاوا) است. امروزه کمتر استفاده می‌شود، اما ممکن است در پروژه‌های قدیمی‌تر پایتون آن را ببینید.</p>
# </div>
# </div>
# </div>

# %%
def multiply(a: float, b: float) -> float:
    """
    دو عدد را ضرب می‌کند.

    @param a: توضیحات a.
    @type a: float
    @param b: توضیحات b.
    @type b: float
    @return: توضیحات مقدار بازگشتی.
    @rtype: float
    """
    return a * b

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .pink { border-right-color: rgb(239, 80, 157); }
# </style>
# <div class='section-card' id='toc5_5_'>
# <div class='container'>
# <div class='card pink'>
# <h3>چگونه یک استایل انتخاب کنیم؟</h3>
# <ul>
# <li><strong>یکپارچگی (Consistency):</strong> از یک استایل ثابت در کل کدهای پروژه استفاده کنید.</li>
# <li><strong>ابزارها (Tooling):</strong> بررسی کنید که ابزارهای تیم شما (مثل Sphinx) با کدام مدل سازگارترند.</li>
# <li><strong>جامعه کاربری (Community):</strong> اگر برای پروژه‌های متن‌باز (Open Source) کد می‌نویسید، قواعد آن‌ها را رعایت کنید.</li>
# <li><strong>خوانایی (Readability):</strong> هدف نهایی، ارتباط موثر با دیگر برنامه‌نویسان است.</li>
# </ul>
# </div>
# </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .green { border-right-color: #66bb6a; }
# </style>
# <div class='section-card' id='toc6_'>
# <h2>۶. راهنمای نوع داده (Type Hints)</h2>
# <div class='container'>
# <div class='card green'>
# <p>از پایتون ۳.۵ به بعد، ابزاری به نام Type Hints اضافه شد که به شما اجازه می‌دهد نوع داده‌ی پارامترها و خروجی تابع را مشخص کنید. این موارد هنگام اجرای کد (Runtime) باعث ارور نمی‌شوند، اما برای نرم‌افزارهای کمکی (مثل VS Code) و مستندسازی فوق‌العاده کاربردی هستند.</p>
# </div>
# <div class='card green' id='toc6_1_'>
# <h3>سینتکس (Syntax)</h3>
# <p>برای اضافه کردن Type Hint، بعد از نام پارامتر یک <code>:</code> می‌گذاریم و نوع آن را می‌نویسیم. برای خروجی تابع هم قبل از گذاشتن دونقطه (Colon) انتهای تابع، از فلش <code>-&gt;</code> استفاده می‌کنیم.</p>
# </div>
# </div>
# </div>

# %%
def greeting(name: str) -> str:
    return f"Hello, {name}"

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .green { border-right-color: #66bb6a; }
# </style>
# <div class='section-card'>
# <div class='container'>
# <div class='card green' id='toc6_2_'>
# <h3>مزایای Type Hints</h3>
# <p>باعث بهبود چشمگیر خوانایی کد می‌شود، ابزارهای بررسی استاتیک (مثل mypy) را فعال می‌کند، پشتیبانی ویرایشگرهایی مثل VS Code (تکمیل خودکار کد) را بهتر می‌کند و به نوعی یک مستندسازی زنده محسوب می‌شود.</p>
# </div>
# <div class='card green' id='toc6_3_'>
# <h3>ترکیب Type Hints با داک‌استرینگ</h3>
# <p>برای داشتن یک داکیومنت بی‌نقص، این دو را با هم ترکیب کنید: از Type Hints برای مشخص کردن "نوع داده" و از داک‌استرینگ برای "توضیح عملکرد و رفتار" استفاده کنید.</p>
# </div>
# </div>
# </div>

# %%
def calculate_area(radius: float) -> float:
    """
    مساحت دایره را بر اساس شعاع محاسبه می‌کند.

    محاسبات بر اساس فرمول زیر انجام می‌شود: pi * radius^2.

    Args:
        radius: شعاع دایره.

    Returns:
        مساحت دایره را برمی‌گرداند.
    """
    return 3.141592653589793 * radius ** 2

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; }
#   .blue { border-right-color: #29b6f6; }
# </style>
# <div class='section-card' id='toc7_'>
# <h2>۷. تمرین عملی</h2>
# <div class='container'>
# <div class='card blue'>
# <p>تابعی بنویسید که مساحت یک مستطیل را محاسبه کند. برای این کار موارد زیر را اعمال کنید:</p>
# </div>
# <div class='card blue'>
# <ol>
# <li><strong>نوشتن تابع:</strong> تابعی با نام <code>calculate_rectangle_area(width, height)</code> تعریف کنید.</li>
# <li><strong>افزودن داک‌استرینگ:</strong> توضیحات، پارامترها و خروجی را در آن ذکر کنید.</li>
# <li><strong>استفاده از Type Hints:</strong> نوع ورودی‌ها و خروجی را <code>float</code> در نظر بگیرید.</li>
# <li><strong>دسترسی:</strong> اطلاعات آن را توسط <code>help()</code> و <code>__doc__</code> پرینت بگیرید.</li>
# <li><strong>پاداش:</strong> سعی کنید داک‌استرینگ خود را کاملاً با استایل <strong>Google</strong> بنویسید.</li>
# </ol>
# </div>
# </div>
# </div>

# %%
# وظیفه ۱، ۲ و ۳: تعریف تابع، نوشتن داک‌استرینگ و اضافه کردن راهنمای نوع داده (Type Annotations)
def calculate_rectangle_area(width: float, height: float) -> float:
    """
    مساحت یک مستطیل را محاسبه می‌کند.

    Parameters:
    width (float): عرض مستطیل.
    height (float): طول (ارتفاع) مستطیل.

    Returns:
    float: مساحت محاسبه شده مستطیل.
    """
    return width * height

# %%
# وظیفه ۴: خواندن داک‌استرینگ
print("استفاده از ویژگی .__doc__:")
# Out:
# استفاده از ویژگی .__doc__:

# %%
print(calculate_rectangle_area.__doc__)
# Out:
#     مساحت یک مستطیل را محاسبه می‌کند.
#
#     Parameters:
#     width (float): عرض مستطیل.
#     height (float): طول (ارتفاع) مستطیل.
#
#     Returns:
#     float: مساحت محاسبه شده مستطیل.

# %%
print("استفاده از تابع help():")
help(calculate_rectangle_area)
# Out:
# استفاده از تابع help():
# Help on function calculate_rectangle_area in module __main__:
#
# calculate_rectangle_area(width: float, height: float) -> float
#     مساحت یک مستطیل را محاسبه می‌کند.
#
#     Parameters:
#     width (float): عرض مستطیل.
#     height (float): طول (ارتفاع) مستطیل.
#
#     Returns:
#     float: مساحت محاسبه شده مستطیل.

# %%
# بخش پاداش: بازنویسی با استایل گوگل (Google Style)
def calculate_rectangle_area(width: float, height: float) -> float:
    """
    مساحت یک مستطیل را محاسبه می‌کند.

    Args:
        width (float): عرض مستطیل.
        height (float): ارتفاع (طول) مستطیل.

    Returns:
        مساحت محاسبه شده مستطیل را برمی‌گرداند.
    """
    return width * height
