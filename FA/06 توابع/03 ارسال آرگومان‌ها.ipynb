# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1 { width: 100%; text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #66bb6a; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   ul { padding-right: 1.25rem; padding-left: 0; }
#   img { display: block; max-width: 50vw; height: auto; margin: 15px auto; border-radius: 10px; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h1 { font-size: 2rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card">
#   <h1>نحوه پاس دادن آرگومان‌ها در پایتون 📥</h1>
# </div>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <p>آرگومان‌های تابع ضروری هستند، زیرا به توابع اجازه می‌دهند روی داده‌های مختلف کار کنند و آن‌ها را همه‌کاره‌تر (Versatile) می‌کنند. وقتی تابعی را تعریف می‌کنید، پارامترهای آن را مشخص می‌کنید و هنگام فراخوانی، آرگومان‌هایی را می‌فرستید که به آن پارامترها اختصاص می‌یابند.</p>
#       <p>پاس دادن داده‌ها اجازه می‌دهد رفتار یک تابع را بدون تغییر در کد اصلی آن سفارشی‌سازی کنید. این کار انعطاف‌پذیری کد را بالا برده و تکرار (Redundancy) را کاهش می‌دهد.</p>
#     </div>
#     <div class="card">
#        <img src="../../images/parameters-arguments.png" alt="نمودار پارامترها در مقابل آرگومان‌ها">
#     </div>
#     <div class="card">
#        <p>در پایان این درس، درک عمیقی از موارد زیر خواهید داشت:</p>
#        <ul>
#          <li>استفاده از <strong>آرگومان‌های موقعیتی</strong> برای ارسال اطلاعات اجباری.</li>
#          <li>بهره‌گیری از <strong>آرگومان‌های کلیدواژه‌ای</strong> برای بهبود خوانایی کد.</li>
#          <li>تعریف توابع با <strong>آرگومان‌های پیش‌فرض</strong> برای افزایش کارایی.</li>
#        </ul>
#        <p style="margin-bottom:0;">علاوه بر این، اصول حرفه‌ای را بررسی می‌کنیم تا مطمئن شویم استفاده شما از آرگومان‌ها شفاف و قابل نگهداری است.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   /* Global Settings */
#   * { box-sizing: border-box; }
#
#   /* Section Card Style */
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   /* Typography */
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#
#   /* Inner Cards */
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#
#   /* Fix for Last Child Margin */
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   /* Images */
#   img { display: block; max-width: 50vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#
#   /* TOC Style */
#   .toc-card ul { list-style-type: none; padding-right: 1rem; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; font-weight: 500; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#   .toc-card ul ul { padding-right: 1.5rem; margin-top: 0.5rem; list-style-type: circle; }
#   .toc-card ul ul li a { color: #dcdcdc; font-weight: normal; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#
#   /* Accent Colors */
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#   .pink { border-right-color: #f06292; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     .section-card h2 { font-size: 1.4rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
# <div class="section-card">
#   <h2>فهرست مطالب</h2>
#   <div class="container">
#     <div class="card blue toc-card">
#     <h3>دسترسی سریع</h3>
#       <ul>
#         <li><a href="#toc1_">۱. آرگومان‌های موقعیتی (Positional)</a></li>
#         <li><a href="#toc2_">۲. آرگومان‌های کلیدواژه‌ای (Keyword)</a></li>
#         <li><a href="#toc3_">۳. پارامترهای پیش‌فرض (Default)</a></li>
#         <li><a href="#toc4_">۴. اصول حرفه‌ای و تمرین</a></li>
#       </ul>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ffa726; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   ul { padding-right: 1.25rem; padding-left: 0; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc1_">
#   <h2>۱. آرگومان‌های موقعیتی (Positional Arguments)</h2>
#   <div class="container">
#     <div class="card">
#       <p>آرگومان‌های موقعیتی ساده‌ترین راه برای انتقال اطلاعات به توابع هستند. آن‌ها بر پایه <strong>ترتیب</strong> آرگومان‌ها کار می‌کنند تا آن‌ها را با پارامترهای تعریف شده در تابع مطابقت دهند.</p>
#       <p>هنگام استفاده از این آرگومان‌ها، دو نکته را به یاد داشته باشید:</p>
#       <ul>
#         <li><strong>ترتیب حیاتی است</strong>: ترتیبی که آرگومان‌ها را پاس می‌دهید باید دقیقاً با ترتیب پارامترها همخوانی داشته باشد.</li>
#         <li><strong>تعداد دقیق آرگومان‌ها</strong>: شما باید دقیقاً به تعداد پارامترهای تعریف شده، آرگومان وارد کنید.</li>
#       </ul>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>ساخت یک تابع برای چاپ پیام دعوت تولد:</strong></p>

# %%
def create_invitation(name, age, date):
    print(f"Dear {name}, you're invited to a birthday party celebrating {age} years on {date}!")

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>فراخوانی تابع با رعایت ترتیب دقیق پارامترها:</strong></p>

# %%
create_invitation('Alice', 10, 'April 21st')
# Out:
# Dear Alice, you're invited to a birthday party celebrating 10 years on April 21st!

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>اگر ترتیب آرگومان‌ها را رعایت نکنیم، نتیجه بی‌معنی خواهد بود:</strong></p>

# %%
# جابجا کردن ترتیب باعث ایجاد یک دعوت‌نامه اشتباه می‌شود
create_invitation(10, 'April 21st', 'Alice')
# Out:
# Dear 10, you're invited to a birthday party celebrating April 21st years on Alice!

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>خطا هنگام کم بودن تعداد آرگومان‌ها:</strong></p>

# %%
create_invitation('Alice', 10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 create_invitation('Alice', 10)
#
# TypeError: create_invitation() missing 1 required positional argument: 'date'

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ba68c8; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc2_">
#   <h2>۲. آرگومان‌های کلیدواژه‌ای (Keyword Arguments)</h2>
#   <div class="container">
#     <div class="card">
#       <p>آرگومان‌های کلیدواژه‌ای به شما اجازه می‌دهند با صدا کردن صریح نام هر پارامتر (به صورت <code>keyword=value</code>)، مقدار آن را مشخص کنید. این کار به شما آزادی می‌دهد تا ترتیب پارامترها را نادیده بگیرید.</p>
#       <p style="margin-bottom:0;">دقت کنید که اگر می‌خواهید از هر دو نوع در یک فراخوانی استفاده کنید، آرگومان‌های موقعیتی <strong>حتماً</strong> باید قبل از آرگومان‌های کلیدواژه‌ای نوشته شوند.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>تابعی برای چاپ جزئیات خرید یک کتاب:</strong></p>

# %%
def print_purchase(book_title, author, price):
    print(f"Purchased book: {book_title} by {author} for ${price}")

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>فراخوانی با کلیدواژه (ترتیب دلخواه):</strong></p>

# %%
# در آرگومان‌های کلیدواژه‌ای، ترتیب اهمیتی ندارد
print_purchase(price=12.99, book_title='Atomic Habits', author='James Clear')
# Out:
# Purchased book: Atomic Habits by James Clear for $12.99

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>ترکیب آرگومان موقعیتی و کلیدواژه‌ای:</strong></p>

# %%
# ابتدا آرگومان موقعیتی و سپس کلیدواژه‌ای
print_purchase('Atomic Habits', price=12.99, author='James Clear')
# Out:
# Purchased book: Atomic Habits by James Clear for $12.99

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ef5350; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc3_">
#   <h2>۳. پارامترهای پیش‌فرض (Default Parameters)</h2>
#   <div class="container">
#     <div class="card">
#       <p style="margin-bottom:0;">پارامترهای پیش‌فرض به توابع اجازه می‌دهند که مقادیر از پیش تعیین شده داشته باشند؛ این کار باعث می‌شود برخی آرگومان‌ها هنگام فراخوانی اختیاری باشند. یادتان باشد که پارامترهای پیش‌فرض همیشه باید <strong>بعد</strong> از پارامترهای اجباری (موقعیتی) در تعریف تابع قرار بگیرند.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>تابعی برای نمایش اطلاعات کاربر با مقادیر پیش‌فرض:</strong></p>

# %%
def create_profile(name, age, country='Unknown', language='English'):
    print(f"Name: {name}, Age: {age}, Country: {country}, Language: {language}")

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>فراخوانی فقط با آرگومان‌های اجباری:</strong></p>

# %%
create_profile('Albert Einstein', 76)
# Out:
# Name: Albert Einstein, Age: 76, Country: Unknown, Language: English

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   p { direction: rtl; font-family: 'Vazirmatn', sans-serif; font-size: 1rem; color: #ffffff; line-height: 1.8; }
# </style>
# <p><strong>تغییر مقدار پیش‌فرض هنگام فراخوانی:</strong></p>

# %%
create_profile('Nikola Tesla', 86, language='Serbian')
# Out:
# Name: Nikola Tesla, Age: 86, Country: Unknown, Language: Serbian

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #66bb6a; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   ul { padding-right: 1.25rem; padding-left: 0; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc4_">
#   <h2>۴. اصول حرفه‌ای و تمرین</h2>
#   <div class="container">
#     <div class="card">
#       <h3>بهترین روش‌ها (Best Practices)</h3>
#       <ul>
#         <li>از <strong>آرگومان‌های موقعیتی</strong> برای پارامترهای اجباری که ترتیب منطقی و مشخصی دارند استفاده کنید.</li>
#         <li>از <strong>آرگومان‌های کلیدواژه‌ای</strong> برای افزایش شفافیت استفاده کنید، مخصوصاً زمانی که تابع پارامترهای زیادی دارد.</li>
#         <li>مقادیر پیش‌فرض معقولی انتخاب کنید تا توابع شما منعطف‌تر و استفاده از آن‌ها راحت‌تر باشد.</li>
#       </ul>
#     </div>
#     <div class="card" id="toc5_">
#        <h3>تمرین: یک روز در باغ وحش</h3>
#        <p>تابعی به نام <code>schedule_visit</code> بنویسید که پارامترهای <code>section</code> (بخش)، <code>time</code> (زمان) و یک پارامتر اختیاری <code>activity</code> (فعالیت) با مقدار پیش‌فرض "Feeding" را بگیرد. سپس آن را یک بار برای بخش "Reptiles" در ساعت "10:00 AM" (با استفاده از مقدار پیش‌فرض) و بار دیگر برای بخش "Birds" در ساعت "1:00 PM" با فعالیت "Educational Talk" فراخوانی کنید.</p>
#     </div>
#   </div>
# </div>

# %%
# کد تمرین را اینجا بنویسید
