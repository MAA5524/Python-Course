# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1 { width: 100%; text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #66bb6a; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   img { display: block; max-width: 40vw; height: auto; margin: 0 auto; border-radius: 10px; }
#   a { color: #29b6f6; text-decoration: none; font-weight: 500; }
#   a:hover { text-decoration: underline; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h1 { font-size: 2rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card">
#   <h1>آشنایی با توابع (Functions) 🧩</h1>
# </div>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <p>توابع، آجرهای سازنده‌ی کدهای قابل استفاده مجدد، سازمان‌یافته و کارآمد هستند. در برنامه‌نویسی، یک تابع می‌تواند ورودی‌هایی (پارامترها) را بگیرد، عملیاتی را روی آن‌ها انجام دهد و خروجی را برگرداند. اما فراتر از این، توابع با ایجاد لایه‌های انتزاعی (Abstraction)، نرم‌افزار را ماژولار و مدیریت آن را آسان‌تر می‌کنند.</p>
#     </div>
#     <div class="card">
#        <img src="../../images/math-function.png" alt="نمودار تابع ریاضی">
#     </div>
#     <div class="card">
#        <p>مفهوم تابع در دنیای واقعی هم وجود دارد. مثلاً یک دستگاه قهوه‌ساز ورودی‌هایی (دانه قهوه، آب) را می‌گیرد، عملیاتی (آسیاب کردن، دم کردن) را انجام می‌دهد و خروجی (قهوه) تولید می‌کند. شما قبلاً از توابع داخلی پایتون مثل <code>id()</code> و <code>len()</code> که کارهای خاصی را انجام می‌دهند، استفاده کرده‌اید.</p>
#     </div>
#     <div class="card">
#        <img src="../../images/vending-function.png" alt="دستگاه فروش خودکار به عنوان تابع">
#     </div>
#     <div class="card">
#       <p>با یادگیری نحوه تعریف توابع شخصی خود، کنترل کاملی بر قابلیت استفاده مجدد و نظم کدهایتان پیدا خواهید کرد.</p>
#       <p>پیشنهاد تماشا: <a href="https://www.youtube.com/watch?v=RU1u-js7db8" target="_blank">چگونه توابع جهان را توصیف می‌کنند؟</a></p>
#     </div>
#   </div>
# </div>

# %%
s = 'foobar'
print(id(s))  # شناسه منحصر به فرد شیء رشته‌ای را برمی‌گرداند

# %%
a = ['foo', 'bar', 'baz', 'qux']
print(len(a))  # تعداد آیتم‌های موجود در لیست را برمی‌گرداند

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   /* Global Settings */
#   * { box-sizing: border-box; }
#
#   /* Section Card Style */
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   /* Typography */
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#
#   /* Inner Cards */
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#
#   /* Fix for Last Child Margin */
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   /* Images */
#   img { display: block; max-width: 50vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#
#   /* TOC Style */
#   .toc-card ul { list-style-type: none; padding-right: 1rem; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; font-weight: 500; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#   .toc-card ul ul { padding-right: 1.5rem; margin-top: 0.5rem; list-style-type: circle; }
#   .toc-card ul ul li a { color: #dcdcdc; font-weight: normal; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#
#   /* Accent Colors */
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#   .pink { border-right-color: #f06292; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     .section-card h2 { font-size: 1.4rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
# <div class="section-card">
#   <h2>فهرست مطالب</h2>
#   <div class="container">
#     <div class="card blue toc-card">
#     <h3>دسترسی سریع</h3>
#       <ul>
#         <li><a href="#toc1_">۱. تابع چیست؟</a></li>
#         <li><a href="#toc2_">۲. اهمیت توابع در پایتون</a>
#           <ul>
#             <li>انتزاع (Abstraction) و قابلیت استفاده مجدد</li>
#             <li>ماژولار بودن (Modularity)</li>
#             <li>جداسازی فضای نام (Namespace)</li>
#           </ul>
#         </li>
#         <li><a href="#toc3_">۳. ساخت اولین تابع شما</a>
#           <ul>
#             <li>سینتکس تعریف تابع</li>
#             <li>سینتکس فراخوانی تابع</li>
#             <li>اولین تابع شما</li>
#             <li>استفاده از پارامترها</li>
#             <li>توابع نگهدارنده با <code>pass</code></li>
#           </ul>
#         </li>
#       </ul>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0,0,0,0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ffa726; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   img { display: block; max-width: 40vw; height: auto; margin: 0 auto; border-radius: 10px; }
#   @media (max-width: 768px) { .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc1_">
#   <h2>۱. تابع چیست؟</h2>
#   <div class="container">
#     <div class="card">
#       <p>یک تابع در برنامه‌نویسی، بلوکی از کد است که برای انجام یک کار مشخص طراحی شده و بارها قابل استفاده است. توابع داده‌ها را می‌گیرند، آن‌ها را پردازش می‌کنند و نتیجه را برمی‌گردانند. در پایتون، توابع به سازماندهی کد کمک کرده و خوانایی آن را بالا می‌برند. این ابزار به شما اجازه می‌دهد کد را <strong>یک‌بار بنویسید و چندین‌بار استفاده کنید</strong> که هسته اصلی اصل <strong>DRY (خودت را تکرار نکن)</strong> است.</p>
#     </div>
#     <div class="card">
#        <img src="../../images/math-function-input-output.png" alt="نمودار ورودی-پردازش-خروجی تابع">
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ba68c8; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   pre { background-color: #1a1a2e; padding: 1rem; border-radius: 8px; direction: ltr; text-align: left; overflow-x: auto; margin-bottom: 1rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc2_">
#   <h2>۲. اهمیت توابع در پایتون</h2>
#   <div class="container">
#     <div class="card">
#       <p>توابع در پایتون حیاتی هستند زیرا باعث ترویج جنبه‌های کلیدی طراحی نرم‌افزار خوب می‌شوند: انتزاع، قابلیت استفاده مجدد، ماژولار بودن و جداسازی فضاهای نام.</p>
#     </div>
#     <div class="card" id="toc2_1_">
#       <h3>انتزاع و قابلیت استفاده مجدد</h3>
#       <p>با قرار دادن منطق برنامه در یک تابع، می‌توانید آن کد را در هر کجای برنامه فقط با فراخوانی نام تابع استفاده کنید. این کار مطابق با اصل DRY بوده و باعث صرفه‌جویی در زمان و کاهش خطاها می‌شود.</p>
#     </div>
# </div>

# %%
def calculate_average(numbers):
    return sum(numbers) / len(numbers)

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ba68c8; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   pre { background-color: #1a1a2e; padding: 1rem; border-radius: 8px; direction: ltr; text-align: left; overflow-x: auto; margin-bottom: 1rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc2_">
#   <div class="container">
#     <div class="card" id="toc2_2_">
#        <h3>ماژولار بودن (Modularity)</h3>
#        <p>ماژولار بودن یعنی شکستن یک سیستم پیچیده به اجزای کوچک‌تر و قابل مدیریت. توابع به شما اجازه می‌دهند برنامه‌ها را به ماژول‌هایی تقسیم کنید که هر کدام مسئولیت خاصی دارند، که این کار فرآیند توسعه و خطایابی را بسیار ساده‌تر می‌کند.</p>
#   </div>
# </div>

# %%
def read_file(filepath):
    # منطق خواندن فایل
    pass

def process_data(data):
    # پردازش داده‌ها
    pass

def write_file(filepath, data):
    # نوشتن داده‌ها در فایل
    pass

contents = read_file('input.txt')
result = process_data(contents)
write_file('output.txt', result)

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ba68c8; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   pre { background-color: #1a1a2e; padding: 1rem; border-radius: 8px; direction: ltr; text-align: left; overflow-x: auto; margin-bottom: 1rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc2_">
#   <div class="container">
#     <div class="card" id="toc2_3_">
#        <h3>جداسازی فضای نام (Namespace Separation)</h3>
#        <p>هر تابع «فضای نام» مخصوص به خود را دارد؛ یعنی متغیرهایی که داخل تابع تعریف می‌شوند، محلی (Local) هستند. این ایزوله‌سازی از تداخل نام متغیرها جلوگیری کرده و رفتار کد را قابل پیش‌بینی می‌کند.</p>
#     </div>
#   </div>
# </div>

# %%
def function_a():
    temp = "func A"
    return temp

def function_b():
    temp = "func B"
    return temp

# هیچ تداخلی بین دو متغیر temp وجود ندارد
print(function_a())
print(function_b())

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ef5350; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   img { display: block; max-width: 50vw; height: auto; margin: 15px auto; border-radius: 10px; }
#   pre { background-color: #1a1a2e; padding: 1rem; border-radius: 8px; direction: ltr; text-align: left; overflow-x: auto; margin-bottom: 1rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc3_">
#   <h2>۳. ساخت اولین تابع شما</h2>
#   <div class="container">
#     <div class="card" id="toc3_1_">
#       <h3>سینتکس تعریف تابع</h3>
#       <p>برای تعریف یک تابع، از کلمه کلیدی <code>def</code> استفاده می‌کنیم که به دنبال آن نام تابع، پرانتزها برای پارامترها و علامت دو نقطه قرار می‌گیرد. بدنه تابع یک بلوک کد تورفته است.</p>
#       <pre style="margin-top: 10px;"><code>def function_name(parameters):
#     statements</code></pre>
#       <img src="../../images/function-parts.png" width="600" alt="اجزای تابع">
#     </div>
#     <div class="card" id="toc3_2_">
#       <h3>سینتکس فراخوانی تابع</h3>
#       <p>برای استفاده از یک تابع، آن را با نامش و پرانتزها صدا بزنید:</p>
#       <pre style="margin-top: 10px;"><code>function_name(arguments)</code></pre>
#       <p>اگر تابع پارامتر می‌خواهد، آرگومان‌ها را داخل پرانتز بگذارید؛ در غیر این صورت از پرانتز خالی <code>()</code> استفاده کنید.</p>
#     </div>
#     <div class="card" id="toc3_3_">
#        <h3>اولین تابع شما</h3>
#        <p>بیایید یک تابع ساده به نام <code>greet</code> بسازیم که پارامتری نمی‌گیرد و فقط یک پیام خوش‌آمدگویی چاپ می‌کند.</p>
#     </div>
#   </div>
# </div>

# %%
def greet():
    print("Hello there, welcome to Python functions!")

greet()
# Out:
# Hello there, welcome to Python functions!

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ef5350; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   @media (max-width: 768px) { .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc3_4_">
#   <div class="container">
#     <div class="card">
#       <h3>استفاده از پارامترها</h3>
#       <p>حالا بیایید تابع را با اضافه کردن یک پارامتر ارتقا دهیم تا بتواند به یک شخص خاص با نام خودش خوش‌آمد بگوید.</p>
#     </div>
#   </div>
# </div>

# %%
def greet(name):
    print(f"Hello, {name}! Welcome to Python functions!")

greet("Alice")
# Out:
# Hello, Alice! Welcome to Python functions!

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ef5350; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc3_5_">
#   <div class="container">
#     <div class="card">
#       <h3>توابع نگهدارنده با دستور <code>pass</code></h3>
#       <p style="margin-bottom:0;">گاهی اوقات ممکن است بخواهید ساختار یک تابع را تعریف کنید اما نوشتن محتوای آن را به بعد موکول کنید. در پایتون، می‌توانید از دستور <code>pass</code> برای این منظور استفاده کنید تا برنامه دچار خطا نشود.</p>
#     </div>
#   </div>
# </div>

# %%
def future_function():
    pass

future_function()  # فعلاً هیچ کاری انجام نمی‌دهد
