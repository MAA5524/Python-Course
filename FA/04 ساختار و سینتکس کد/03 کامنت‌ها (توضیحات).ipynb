# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1 { width: 100%; text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #66bb6a; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h1 { font-size: 2rem; } .card { width: 100%; padding: 1rem; } }
# </style>
#
# <div class="section-card">
#   <h1>کامنت‌ها: بیان هدف در کدنویسی 📝</h1>
# </div>
# <div class="section-card">
#   <div class="container">
#     <div class="card">
#       <p>کامنت‌ها در پایتون یادداشت‌هایی برای برنامه‌نویسان هستند (شامل خودتان در آینده) که توضیح می‌دهند در کد چه اتفاقی می‌افتد. وجود آن‌ها برای قابل‌فهم‌تر شدن و نگهداری آسان‌تر کد بسیار حیاتی است.</p>
#       <p>هر کامنت با علامت هش <code>#</code> شروع می‌شود و تا انتهای آن خط ادامه می‌یابد. مفسر پایتون هر چیزی که بعد از علامت <code>#</code> بیاید را نادیده می‌گیرد.</p>
#     </div>
#     <div class="card">
#       <p>کامنت‌ها فقط برای توضیح موارد واضح نیستند؛ آن‌ها زمینه (Context) و منطق انجام یک کار را بیان می‌کنند. کد شما به ما می‌گوید <strong>چگونه</strong> کاری انجام شده، اما کامنت می‌تواند بگوید <strong>چرا</strong> آن کار انجام شده است.</p>
#       <p style="margin-bottom:0;">عادت به نوشتن کامنت‌های خوب، ساعت‌ها در وقت شما و تیم‌تان صرفه‌جویی خواهد کرد.</p>
#     </div>
#   </div>
# </div>

# %%
# محاسبه توان دوم یک عدد
square = 5 ** 2

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   /* Global Settings */
#   * { box-sizing: border-box; }
#
#   /* Section Card Style */
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   /* Typography */
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#
#   /* Inner Cards */
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#
#   /* Fix for Last Child Margin */
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   /* Images */
#   img { display: block; max-width: 50vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#
#   /* TOC Style */
#   .toc-card ul { list-style-type: none; padding-right: 1rem; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; font-weight: 500; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#   .toc-card ul ul { padding-right: 1.5rem; margin-top: 0.5rem; list-style-type: circle; }
#   .toc-card ul ul li a { color: #dcdcdc; font-weight: normal; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#
#   /* Accent Colors */
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#   .pink { border-right-color: #f06292; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     .section-card h2 { font-size: 1.4rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
# <div class="section-card">
#   <h2>فهرست مطالب</h2>
#   <div class="container">
#     <div class="card blue toc-card">
#     <h3>دسترسی سریع</h3>
#       <ul>
#         <li><a href="#toc1_">۱. استفاده موثر از کامنت‌ها</a>
#           <ul>
#             <li>کامنت‌های تک‌خطی</li>
#             <li>کامنت‌های درون‌خطی (Inline)</li>
#             <li>غیرفعال کردن کد (Commenting Out)</li>
#             <li>کامنت‌های چندخطی</li>
#           </ul>
#         </li>
#         <li><a href="#toc2_">۲. داک‌استرینگ‌ها (Docstrings)</a></li>
#         <li><a href="#toc3_">۳. اصول حرفه‌ای در نوشتن کامنت</a></li>
#       </ul>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ffa726; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc1_">
#   <h2>۱. استفاده موثر از کامنت‌ها</h2>
#   <div class="container">
#     <div class="card orange" id="toc1_1_">
#       <h3>کامنت‌های تک‌خطی و درون‌خطی</h3>
#       <p>کامنت‌های تک‌خطی با <code>#</code> شروع می‌شوند و برای توضیحات کوتاه یا غیرفعال کردن موقت کد استفاده می‌شوند. آن‌ها می‌توانند در یک خط جداگانه یا در انتهای خطِ کد (درون‌خطی) قرار بگیرند.</p>
#     </div>
#     <div class="card orange" id="toc1_3_">
#        <h3>غیرفعال کردن کد (Commenting Out)</h3>
#        <p>در طول توسعه، می‌توانید بخش‌هایی از کد خود را با اضافه کردن یک <code>#</code> در ابتدای هر خط به طور موقت غیرفعال کنید تا اجرا نشوند.</p>
#     </div>
#     <div class="card orange" id="toc1_4_">
#       <h3>کامنت‌های چندخطی</h3>
#       <p>پایتون سینتکس خاصی برای کامنت چندخطی ندارد. روش استاندارد، استفاده از چند کامنت تک‌خطی پشت سر هم است. روش دیگر، استفاده از رشته‌های سه کوتیشن (<code>'''...'''</code>) است که به هیچ متغیری نسبت داده نشده باشند؛ اگرچه این روش رسماً برای داک‌استرینگ‌ها استفاده می‌شود.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# **کامنت تک‌خطی**

# %%
# این یک کامنت تک‌خطی در پایتون است
# print("این خط اجرا نخواهد شد چون کامنت شده است")

# %% [markdown]
# **کامنت درون‌خطی (Inline)**

# %%
x = 10  # اختصاص عدد ۱۰ به متغیر x

# %% [markdown]
# **غیرفعال کردن کد**

# %%
# print("این خط کامنت شده و اجرا نمی‌شود")
# x = x + 1  # این افزایش مقدار اتفاق نمی‌افتد

# %% [markdown]
# **کامنت‌های چندخطی**

# %% [markdown]
# استفاده از چند علامت # متوالی

# %%
# کد زیر فاکتوریل یک عدد را محاسبه
# و نتیجه را چاپ می‌کند. فاکتوریل یک عدد
# حاصل‌ضرب تمام اعداد صحیح از ۱ تا آن عدد است.

# %% [markdown]
# استفاده از رشته‌های سه کوتیشن (Triple-quoted strings)

# %%
"""
این یک کامنت چندخطی یا بلوکی است.
کد زیر فاکتوریل عدد ۵ را محاسبه می‌کند.
"""
# Out:
# '\nاین یک کامنت چندخطی یا بلوکی است.\nکد زیر فاکتوریل عدد ۵ را محاسبه می‌کند.\n'

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ba68c8; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc2_">
#   <h2>۲. داک‌استرینگ‌ها (Docstrings)</h2>
#   <div class="container">
#     <div class="card">
#       <p style="margin-bottom:0;">داک‌استرینگ‌ها (Docstrings) کامنت‌های خاصی هستند که برای مستندسازی کد به کار می‌روند. آن‌ها به عنوان اولین دستور در داخل یک ماژول، تابع، کلاس یا متد نوشته شده و در بین سه کوتیشن قرار می‌گیرند. این متون توسط ابزارهایی مثل Sphinx برای تولید خودکار دفترچه راهنمای کد استفاده می‌شوند.</p>
#     </div>
#   </div>
# </div>

# %%
def add(a, b):
    """
    دو عدد را با هم جمع کرده و نتیجه را برمی‌گرداند.

    پارامترها:
    a (int): عدد اول برای جمع.
    b (int): عدد دوم برای جمع.

    خروجی:
    int: حاصل‌جمع a و b.
    """
    return a + b

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid #ef5350; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; }
#   ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   li { margin-bottom: 0.5rem; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc3_">
#   <h2>۳. اصول حرفه‌ای در نوشتن کامنت</h2>
#   <div class="container">
#     <div class="card">
#       <ol>
#         <li>کامنت‌ها را کوتاه، مختصر و مرتبط نگه دارید.</li>
#         <li>اگر کد را تغییر دادید، حتماً کامنت‌های مربوط به آن را هم بروزرسانی کنید.</li>
#         <li>از توضیح موارد بدیهی خودداری کنید؛ به جای «چگونه»، روی «چرا» تمرکز کنید.</li>
#         <li>از کامنت‌ها برای شفاف‌سازی کدهای پیچیده یا الگوریتم‌های خاص استفاده کنید.</li>
#         <li>در سراسر پروژه از یک استایل ثابت برای نوشتن توضیحات استفاده کنید.</li>
#       </ol>
#     </div>
#     <div class="card">
#        <p style="margin-bottom:0;">استفاده صحیح از کامنت‌ها، خوانایی و درک کد شما را به شدت افزایش می‌دهد. با صرف زمان برای مستندسازی اصولی کد، شما در واقع روی شفافیت و کارآمدیِ آینده‌ی خود و همکارانتان سرمایه‌گذاری می‌کنید.</p>
#     </div>
#   </div>
# </div>
