# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h1>💻 پروژه اول: پردازشگر پیام‌های پلتفرم اکو</h1>
#   <div class="container">
#     <div class="card blue">
#       <p>در این پروژه، داده‌های خام ارسال پیامک‌های سیستمی را از سرور پلتفرم «اکو» (Echo) پردازش خواهید کرد. این تمرین آموخته‌های شما از فصل سوم و چهارم (انواع داده‌ها، کار با رشته‌ها، اسلایسینگ، آنپکینگ، تاپل‌ها، دیکشنری‌ها، محاسبات ریاضی و فرمت‌بندی پیشرفته با <code>f-string</code>) را در <strong>۳ مرحله تصاعدی (از آسان به سخت)</strong> به چالش می‌کشد.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h2>مرحله ۱: تمیزکاری و نرمال‌سازی داده‌های خام (آسان)</h2>
#   <div class="container">
#     <div class="card blue">
#       <h3>صورت مسئله</h3>
#       <p>رشته‌ی خام <code>raw_sms_data</code> از سرور با نویزهای ناخواسته در ابتدا و انتها (فاصله‌های اضافی و نمادهای <code>$$</code>) دریافت شده است. اقدامات زیر را انجام دهید:</p>
#       <ul>
#         <li>تمام فاصله‌ها و کاراکترهای <code>$</code> را از ابتدا و انتهای رشته پاک‌سازی کنید و نتیجه را در <code>cleaned_sms</code> ذخیره نمایید.</li>
#         <li>طول رشته‌ی خام اولیه و طول رشته‌ی تمیز شده را با تابع <code>len()</code> محاسبه و چاپ کنید.</li>
#         <li>متغیر <code>cleaned_sms</code> را چاپ کنید.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>نکته‌ی مرحله ۱</h3>
#       <p>می‌توانید از متد <strong>strip()</strong> با آرگومان مناسب یا زنجیره‌ای از متدها برای زدودن کاراکترهای نویز استفاده کنید.</p>
#     </div>
#     <div class="card purple">
#       <h3>خروجی مورد انتظار</h3>
#       <p style="text-align: left; direction: ltr;">
#       <code>Raw Length: 112</code><br>
#       <code>Cleaned Length: 102</code><br>
#       <code>Cleaned SMS: MSG-9821|09123456789|09351112233|System|Security|Alert|Your account is activated|SUCCESS|2026|15450.75</code>
#     </p>
#     </div>
#   </div>
# </div>

# %%
# داده‌ی خام دریافتی از سرور
raw_sms_data = "   $$MSG-9821|09123456789|09351112233|System|Security|Alert|Your account is activated|SUCCESS|2026|15450.75$$   "

# کدهای مرحله ۱ را زیر این خط بنویسید:

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h2>مرحله ۲: تجزیه ساختاریافته و Unpacking پیشرفته (متوسط)</h2>
#   <div class="container">
#     <div class="card orange">
#       <h3>صورت مسئله</h3>
#       <p>رشته‌ی <code>cleaned_sms</code> شامل بخش‌های مختلفی است که با کاراکتر <code>|</code> از هم جدا شده‌اند. به دلیل متغیر بودن طول متن پیام‌ها، باید با تکنیک‌های پیشرفته آن را تجزیه کنید:</p>
#       <ul>
#         <li>رشته را با کاراکتر <code>|</code> به بخش‌های سازنده بشکنید.</li>
#         <li>با استفاده از تکنیک <strong>Extended Unpacking</strong> (علامت <code>*</code>)، داده‌ها را مستقیماً به متغیرهای <code>msg_id</code>، <code>sender</code>، <code>receiver</code>، <code>*message_parts</code>، <code>status</code>، <code>year_str</code> و <code>cost_str</code> تفکیک نمایید.</li>
#         <li>بخش‌های پیام متنی (<code>message_parts</code>) را به یک <strong>tuple</strong> به نام <code>message_tuple</code> تبدیل کنید.</li>
#         <li>متغیر <code>status</code> را با متد <strong>upper()</strong> استانداردسازی کنید.</li>
#         <li>متغیر <code>year_str</code> را به <strong>int</strong> و <code>cost_str</code> را به <strong>float</strong> تبدیل نمایید (به نام‌های <code>year</code> و <code>cost</code>).</li>
#         <li>تمام متغیرها را همراه با نوع داده (<strong>type</strong>) مطابق الگوی خروجی چاپ کنید.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>نکته‌ی مرحله ۲</h3>
#       <p>تکنیک <code>*message_parts</code> در فرآیند Unpacking به شما اجازه می‌دهد تمام بخش‌های میانی متن پیام را به صورت یکجا دریافت کنید بدون اینکه نیازی به شمردن دستی ایندکس‌ها باشد.</p>
#     </div>
#     <div class="card purple">
#       <h3>خروجی مورد انتظار</h3>
#       <p style="text-align: left; direction: ltr;"><code>ID: MSG-9821 (Type: str)</code><br>
#       <code>Sender: 09123456789</code><br>
#       <code>Receiver: 09351112233</code><br>
#       <code>Messages: ('System', 'Security', 'Alert', 'Your account is activated') (Type: tuple)</code><br>
#       <code>Status: SUCCESS</code><br>
#       <code>Year: 2026 (Type: int)</code><br>
#       <code>Cost: 15450.75 (Type: float)</code></p>
#     </div>
#   </div>
# </div>

# %%
# کدهای مرحله ۲ را زیر این خط بنویسید:

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h2>مرحله ۳: ماسک‌گذاری امنیتی، پردازش متنی و ساخت دیکشنری (سخت)</h2>
#   <div class="container">
#     <div class="card blue">
#       <h3>صورت مسئله</h3>
#       <p>در سامانه‌های تراکنشی، حفظ حریم خصوصی و ساختاردهی به اطلاعات الزامی است. در این مرحله:</p>
#       <ul>
#         <li><strong>ماسک‌گذاری شماره تلفن‌ها (Slicing):</strong> برای شماره‌های <code>sender</code> و <code>receiver</code>، ۴ رقم اول و ۴ رقم آخر را حفظ کرده و ۳ رقم میانی را با <code>***</code> بپوشانید (مثال: <code>0912***6789</code>) و در <code>masked_sender</code> و <code>masked_receiver</code> قرار دهید.</li>
#         <li><strong>یکپارچه‌سازی متن پیام:</strong> اعضای <code>message_tuple</code> را با استفاده از متد <strong>join</strong> و جداکننده‌ی <code>" - "</code> به یک متن یکپارچه به نام <code>full_message</code> تبدیل کنید و تعداد کل کاراکترهای آن را در <code>total_chars</code> محاسبه نمایید.</li>
#         <li><strong>محاسبات مالی:</strong> ۱۰٪ مالیات بر ارزش افزوده برای <code>cost</code> محاسبه کرده و در <code>tax_amount</code> ذخیره کنید. مبلغ نهایی (هزینه پایه + مالیات) را در <code>total_cost</code> قرار دهید (مقادیر مالی را با تابع <code>round(..., 2)</code> تا ۲ رقم اعشار گرد کنید).</li>
#         <li><strong>ساخت دیکشنری رکورد نهایی:</strong> یک دیکشنری ساختاریافته به نام <code>processed_record</code> شامل کلیدهای <code>id</code>، <code>sender</code>، <code>receiver</code>، <code>message</code>، <code>char_count</code>، <code>status</code>، <code>year</code>، <code>cost</code>، <code>tax</code> و <code>total_cost</code> بسازید و آن را چاپ نمایید.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>نکته‌ی مرحله ۳</h3>
#       <p>از برش رشته‌ها (String Slicing) به صورت <code>phone[:4] + "***" + phone[7:]</code> برای پوشاندن امنیتی شماره‌ها استفاده کنید.</p>
#     </div>
#     <div class="card purple">
#       <h3>خروجی مورد انتظار</h3>
#       <p style="text-align: left; direction: ltr;"><code>Processed Record:</code><br>
#       <code>{'id': 'MSG-9821', 'sender': '0912***6789', 'receiver': '0935***2233', 'message': 'System - Security - Alert - Your account is activated', 'char_count': 53, 'status': 'SUCCESS', 'year': 2026, 'cost': 15450.75, 'tax': 1545.08, 'total_cost': 16995.83}</code></p>
#     </div>
#   </div>
# </div>

# %%
# کدهای مرحله ۳ را زیر این خط بنویسید:
