# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h1>🚗 پروژه دوم: هسته امنیتی کوپارک</h1>
#   <div class="container">
#     <div class="card blue">
#       <p>به سیستم امنیتی و مدیریت هوشمند پارکینگ طبقاتی «کوپارک» (KooPark) خوش آمدید! در این پروژه، شما مسئولیت پردازش پلاک‌های ثبت‌شده توسط دوربین‌های ورودی، بررسی وضعیت رزروها، شناسایی متخلفین، لایه‌بندی امنیتی داده‌ها با <code>frozenset</code> و ادغام تنظیمات سیستمی را بر عهده دارید. این تمرین مهارت‌های شما در کار با مجموعه‌ها، دیکشنری‌ها، متدهای تحلیلی و فرمت‌بندی را در <strong>۴ مرحله تصاعدی (از آسان به سخت)</strong> ارزیابی می‌کند.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h2>مرحله ۱: پاک‌سازی، نرمال‌سازی و ایجاد مجموعه‌ها (آسان)</h2>
#   <div class="container">
#     <div class="card blue">
#       <h3>صورت مسئله</h3>
#       <p>اطلاعات پلاک‌های رزرو شده (<code>reserved_plates_data</code>)، پلاک‌های وارد شده به پارکینگ (<code>entered_plates_data</code>) و اعضای طلایی VIP (<code>vip_members_data</code>) به صورت رشته‌های متنی با حروف نامنظم و فاصله‌های اضافی دریافت شده‌اند:</p>
#       <ul>
#         <li>با حذف فاصله‌ها و تبدیل حروف به حروف بزرگ (<strong>upper</strong>)، رشته‌ها را بر اساس ویرگول (<code>,</code>) تجزیه کنید.</li>
#         <li>جهت حذف داده‌های تکراری و فراهم‌سازی امکان مقایسه سریع، هر کدام را به ساختار <strong>مجموعه (set)</strong> تبدیل کرده و در متغیرهای <code>reserved_set</code>، <code>entered_set</code> و <code>vip_set</code> ذخیره نمایید.</li>
#         <li>تعداد پلاک‌های یکتا در هر مجموعه را با تابع <code>len()</code> محاسبه کرده و لیست مرتب‌شده‌ی پلاک‌های هر مجموعه را چاپ کنید.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>نکته‌ی مرحله ۱</h3>
#       <p>استفاده از <code>.replace(" ", "").upper().split(",")</code> و سپس پاس دادن خروجی به <code>set()</code> به شما یک مجموعه تمیز، یکپارچه و بدون عضو تکراری می‌دهد.</p>
#     </div>
#     <div class="card purple">
#       <h3>خروجی مورد انتظار</h3>
#       <p style="text-align: left; direction: ltr;"><code>Reserved Set (6 plates): ['11A11', '22B22', '33C33', '77W77', '88Y88', '99Z99']</code><br>
#       <code>Entered Set  (6 plates): ['11A11', '22B22', '44D44', '55E55', '66K66', '77X77']</code><br>
#       <code>VIP Set      (4 plates): ['11A11', '33C33', '55E55', '99Z99']</code></p>
#     </div>
#   </div>
# </div>

# %%
# داده‌های ورودی سامانه کوپارک
reserved_plates_data = "  11A11 , 22B22, 33C33, 99Z99, 88Y88, 22B22, 77W77  "
entered_plates_data = "22b22, 44D44, 55E55, 11A11, 77X77, 44d44, 66K66"
vip_members_data = "33C33, 11A11, 99Z99, 55E55"

# کدهای مرحله ۱ را زیر این خط بنویسید:

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h2>مرحله ۲: جبر مجموعه‌ها و ایجاد لایه امنیتی Frozenset (متوسط)</h2>
#   <div class="container">
#     <div class="card orange">
#       <h3>صورت مسئله</h3>
#       <p>با استفاده از عملگرهای ریاضی مجموعه‌ها (تفاضل <code>-</code> و اشتراک <code>&</code>)، تحلیل‌های امنیتی پارکینگ را استخراج کنید:</p>
#       <ul>
#         <li><strong>پلاک‌های متخلف (ورود بدون رزرو):</strong> تفاضل <code>entered_set - reserved_set</code> را محاسبه کنید. برای ایمن‌سازی این داده‌ها در برابر هرگونه تغییر در ادامه برنامه، آن را به یک <strong>frozenset</strong> تبدیل کرده و در <code>illegal_plates</code> ذخیره نمایید.</li>
#         <li><strong>پلاک‌های غایب (رزرو کرده ولی نیامده‌اند):</strong> تفاضل <code>reserved_set - entered_set</code> را در متغیر <code>absent_plates</code> ذخیره کنید.</li>
#         <li><strong>پلاک‌های مجاز حاضر:</strong> اشتراک <code>entered_set & reserved_set</code> را در <code>authorized_plates</code> ذخیره کنید.</li>
#         <li><strong>خودروهای VIP حاضر:</strong> اشتراک <code>entered_set & vip_set</code> را در <code>active_vips</code> ذخیره نمایید.</li>
#         <li>با متد <strong>issubset()</strong> بررسی کنید آیا تمام اعضای <code>active_vips</code> زیرمجموعه‌ی <code>entered_set</code> هستند یا خیر و نتیجه منطقی را در <code>is_vip_subset</code> ذخیره و چاپ کنید.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>نکته‌ی مرحله ۲</h3>
#       <p>ساختار <code>frozenset</code> یک مجموعه‌ی غیرقابل‌تغییر (Immutable) است و بهترین گزینه برای داده‌های حساس و امنیتی مثل لیست متخلفین محسوب می‌شود.</p>
#     </div>
#     <div class="card purple">
#       <h3>خروجی مورد انتظار</h3>
#       <p style="text-align: left; direction: ltr;"><code>Illegal Plates (frozenset): ['44D44', '55E55', '66K66', '77X77'] | Type: frozenset</code><br>
#       <code>Absent Plates: ['33C33', '77W77', '88Y88', '99Z99']</code><br>
#       <code>Authorized Plates: ['11A11', '22B22']</code><br>
#       <code>Active VIPs: ['11A11', '55E55']</code><br>
#       <code>Is VIP Subset of Entered: True</code></p>
#     </div>
#   </div>
# </div>

# %%
# کدهای مرحله ۲ را زیر این خط بنویسید:

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h2>مرحله ۳: تجزیه تنظیمات ادمین و ادغام دیکشنری‌ها (نیمه‌سخت)</h2>
#   <div class="container">
#     <div class="card blue">
#       <h3>صورت مسئله</h3>
#       <p>سیستم دارای یک دیکشنری پیکربندی پیش‌فرض (<code>default_config</code>) است. همچنین رشته‌ای از تنظیمات و نرخ‌های جدید توسط ادمین در متغیر <code>admin_config_str</code> ارسال شده است:</p>
#       <ul>
#         <li>رشته <code>admin_config_str</code> را با کاراکتر <code>;</code> تفکیک کرده و هر آیتم را بر اساس <code>=</code> به کلید و مقدار تبدیل کنید.</li>
#         <li>انواع داده‌ها را با دقت تبدیل کنید: <code>theme</code> به <strong>str</strong>، <code>capacity</code> به <strong>int</strong>، و <code>hourly_rate</code>، <code>penalty_rate</code> و <code>vip_discount</code> به <strong>float</strong>.</li>
#         <li>دیکشنری حاصل را در <code>admin_config</code> قرار دهید.</li>
#         <li>با استفاده از عملگر ادغام دیکشنری (<strong>|</strong> یا آنپکینگ <strong>**</strong>)، <code>default_config</code> را با <code>admin_config</code> ادغام نمایید به گونه‌ای که تنظیمات ادمین جایگزین پیش‌فرض‌ها شوند.</li>
#         <li>فیلدهای آماری لحظه‌ای زیر را نیز به دیکشنری سیستم اضافه کنید:
#           <ul>
#             <li><code>"occupied_spots"</code>: تعداد خودروهای حاضر (<code>len(entered_set)</code>)</li>
#             <li><code>"available_spots"</code>: ظرفیت باقی‌مانده (ظرفیت منهای خودروهای حاضر)</li>
#             <li><code>"illegal_count"</code>: تعداد خودروهای متخلف (<code>len(illegal_plates)</code>)</li>
#           </ul>
#         </li>
#         <li>دیکشنری نهایی را در <code>system_config</code> ذخیره کرده و چاپ نمایید.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>نکته‌ی مرحله ۳</h3>
#       <p>می‌توانید با استفاده از اندیس‌گذاری و <code>split("=")</code> روی هر آیتم، مقادیر را استخراج و با تبدیل صریح نوع (Type Casting) داخل دیکشنری قرار دهید.</p>
#     </div>
#     <div class="card purple">
#       <h3>خروجی مورد انتظار</h3>
#       <p style="text-align: left; direction: ltr;"><code>System Config:</code><br>
#       <code>{'theme': 'dark', 'capacity': 150, 'hourly_rate': 14000.0, 'vip_discount': 0.25, 'auto_barrier': True, 'penalty_rate': 25000.0, 'occupied_spots': 6, 'available_spots': 144, 'illegal_count': 4}</code></p>
#     </div>
#   </div>
# </div>

# %%
# پیکربندی پیش‌فرض سیستم و رشته تنظیمات ادمین
default_config = {
    "theme": "light",
    "capacity": 100,
    "hourly_rate": 10000.0,
    "vip_discount": 0.20,
    "auto_barrier": True
}
admin_config_str = "theme=dark;capacity=150;hourly_rate=14000.0;penalty_rate=25000.0;vip_discount=0.25"

# کدهای مرحله ۳ را زیر این خط بنویسید:

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     h2 { font-size: 1.5rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h2>مرحله ۴: مرتب‌سازی، محاسبات مالی و تولید داشبورد مدیریتی (سخت)</h2>
#   <div class="container">
#     <div class="card orange">
#       <h3>صورت مسئله</h3>
#       <p>در آخرین گام، داشبورد جامع مانیتورینگ امنیتی و گزارش مالی را با استفاده از <code>f-string</code>های پیشرفته پیاده‌سازی کنید:</p>
#       <ul>
#         <li>پلاک‌های متخلف (<code>illegal_plates</code>) و پلاک‌های مجاز (<code>authorized_plates</code>) را با تابع <strong>sorted()</strong> مرتب نمایید.</li>
#         <li><strong>محاسبات مالی:</strong>
#           <ul>
#             <li>مجموع جرایم متخلفین: <code>total_penalties = illegal_count * penalty_rate</code></li>
#             <li>درآمد تخمینی از خودروهای مجاز (با فرض ۲ ساعت توقف): <code>authorized_revenue = len(authorized_plates) * hourly_rate * 2</code></li>
#             <li>کل درآمد پیش‌بینی‌شده: <code>estimated_total = total_penalties + authorized_revenue</code></li>
#           </ul>
#         </li>
#         <li>داشبورد مدیریتی را با کادربندی ۴۸ کاراکتری <code>#</code> و خطوط جداکننده <code>-</code>، تراز مرکزی عنوان، و نمایش فرمت اعداد مالی با کامای هزارگان و دو رقم اعشار (<code>:&gt;12,.2f</code>) به صورت دقیق چاپ نمایید.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>نکته‌ی مرحله ۴</h3>
#       <p>رعایت کامنت‌گذاری تمیز، فاصله‌گذاری استاندارد و استفاده از رشته‌های چندخطی از اهداف اصلی فصل چهارم در این مرحله است.</p>
#     </div>
#     <div class="card purple">
#       <h3>خروجی مورد انتظار</h3>
#       <pre style="background: rgba(0,0,0,0.5); padding: 1rem; border-radius: 8px; color: #ffab40; font-family: monospace; direction: ltr; text-align: left;">
# ################################################
#     KOOPARK SECURITY & MANAGEMENT DASHBOARD
# ################################################
# Capacity Status   : 6/150 spots occupied (144 available)
# Active Theme      : DARK
# Auto Barrier      : True
# ------------------------------------------------
# Authorized Plates : ['11A11', '22B22']
# Illegal Plates    : ['44D44', '55E55', '66K66', '77X77']
# Active VIPs       : ['11A11', '55E55']
# ------------------------------------------------
# Hourly Rate       :    14,000.00 IRR
# Penalty Rate      :    25,000.00 IRR
# Total Penalties   :   100,000.00 IRR
# Est. Total Income :   156,000.00 IRR
# ################################################</pre>
#     </div>
#   </div>
# </div>

# %%
# کدهای مرحله ۴ را زیر این خط بنویسید:
