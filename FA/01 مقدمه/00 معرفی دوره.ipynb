# %% [markdown]
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;700&display=swap');
#
#     * {
#       box-sizing: border-box;
#     }
#     .section-card {
#       background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#       border-radius: 15px;
#       padding: 2rem;
#       margin: 0 auto 2.5rem;
#       box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5);
#       width: 100%;
#       max-width: 95vw;
#       direction: rtl; /* راست‌چین کردن کل بخش */
#       font-family: 'Vazirmatn', sans-serif;
#     }
#     .section-card h1, .section-card h2 {
#       text-align: center;
#       color: #ffffff;
#       margin-bottom: 1.5rem;
#       font-weight: 700;
#     }
#     .section-card h1 {
#       font-size: 2.5rem;
#     }
#     .section-card h2 {
#       font-size: 1.5rem;
#       color: #e0e0e0;
#     }
#     .container {
#       display: flex;
#       flex-direction: column;
#       gap: 1.25rem;
#       align-items: center;
#     }
#     .card {
#       background: linear-gradient(145deg, #24243e, #1e1e3a);
#       border-radius: 12px;
#       padding: 1.5rem;
#       box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4);
#       border-right: 4px solid transparent; /* تغییر به راست برای فارسی */
#       width: 90vw;
#       margin: 0 auto 1.25rem;
#       transition: transform 0.3s ease, box-shadow 0.3s ease;
#     }
#     .card:hover {
#       transform: translateY(-6px);
#       box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5);
#     }
#     .container > .card:last-child {
#       margin-bottom: 2rem;
#     }
#     .card h3 {
#       color: #ffffff;
#       font-size: 1.3rem;
#       margin-bottom: 0.75rem;
#       font-weight: bold;
#     }
#     p, li {
#       color: #dcdcdc;
#       font-size: 1rem;
#       line-height: 1.8;
#     }
#     p {
#       margin-bottom: 0.75rem;
#     }
#     ul, ol {
#       padding-right: 1.25rem; /* تغییر به راست برای فارسی */
#       padding-left: 0;
#       margin-bottom: 0.75rem;
#     }
#     li {
#       margin-bottom: 0.5rem;
#     }
#     /* رنگ حاشیه راست کارت‌ها */
#     .card.green { border-right-color: #66bb6a; }
#     .card.blue { border-right-color: #29b6f6; }
#     .card.orange { border-right-color: #ffa726; }
#     .card.purple { border-right-color: #ba68c8; }
#     .card.red { border-right-color: #ef5350; }
#     .card.gray { border-right-color: #9e9e9e; }
#
#     .book-grid {
#       display: flex;
#       justify-content: space-around;
#       flex-wrap: wrap;
#       gap: 1rem;
#       margin-top: 1rem;
#     }
#     .book-item {
#       text-align: center;
#       width: 150px;
#     }
#     .book-item img {
#       width: 120px;
#       height: auto;
#       border-radius: 5px;
#       box-shadow: 0 4px 8px rgba(0,0,0,0.3);
#       margin-bottom: 8px;
#     }
#     .book-item span {
#       font-size: 0.85rem;
#       color: #ffffff;
#       display: block;
#       direction: ltr; /* نام انگلیسی کتاب‌ها چپ‌چین بماند */
#     }
#
#     .note {
#       background-color: #fdd835;
#       color: #000;
#       padding: 1rem;
#       border-radius: 6px;
#       margin-top: 1.25rem;
#       font-size: 0.95rem;
#       font-weight: bold;
#       width: min(900px, 90vw);
#       margin: 1.25rem auto 0;
#     }
#     .note strong {
#       color: #d32f2f;
#     }
#     .image-card img {
#       max-width: 40vw;
#       height: auto;
#       display: block;
#       margin: 15px auto;
#       border-radius: 8px;
#     }
#     .card a {
#       color: #29b6f6;
#       text-decoration: none;
#       transition: color 0.3s ease;
#     }
#     .card a:hover {
#       color: #66bb6a;
#       text-decoration: underline;
#     }
#     @media (max-width: 768px) {
#       .section-card { padding: 1.25rem; }
#       .card { width: 100%; padding: 1rem; margin: 0 auto 1rem; }
#       .section-card h1 { font-size: 1.8rem; }
#       .section-card h2 { font-size: 1.2rem; }
#       .book-item { width: 100px; }
#       .book-item img { width: 80px; }
#       .image-card img { max-width: 80vw; }
#     }
# </style>
#
# <div class="section-card">
#   <h1>به دوره آموزش برنامه‌نویسی پایتون خوش آمدید 🐍</h1>
# </div>
#
# <div class="section-card">
#   <div class="container">
#     <div class="card image-card blue" style="text-align:center;">
#       <h3>سلام! خوش اومدی 👋</h3>
#       <p>خیلی خوشحالم که اینجایی. این دوره طراحی شده تا پایتون رو از پایه، در قالب درس‌های کوتاه و کاربردی بهت یاد بده. ما توضیحات رو با مثال‌های عملی ترکیب کردیم تا بتونی همزمان روی سیستم خودت کدها رو تمرین کنی و کامل یاد بگیری.</p>
#       <img src="https://www.mygreatlearning.com/blog/wp-content/uploads/2019/08/python-libraries-2.jpg" alt="کد پایتون روی لپ‌تاپ">
#     </div>
#     <div class="card orange">
#       <h3>چرا یادگیری پایتون مهمه؟</h3>
#       <ul>
#         <li>پایتون یکی از ساده‌ترین و لذت‌بخش‌ترین زبان‌های برنامه‌نویسی برای یادگیریه.</li>
#         <li>بهت کمک می‌کنه تا ایده‌هات رو خیلی سریع به برنامه‌های واقعی و کاربردی تبدیل کنی.</li>
#         <li>ابزاریه که باعث صرفه‌جویی در زمان و افزایش چشمگیر بهره‌وری می‌شه.</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>این دوره برای چه کسانی مناسبه؟</h3>
#       <ul>
#         <li><strong>مبتدی‌هایی</strong> که می‌خوان برنامه‌نویسی رو تازه شروع کنن.</li>
#         <li><strong>دانشجویانی</strong> که برای پروژه‌های دانشگاهی به پایتون نیاز دارن.</li>
#         <li><strong>برنامه‌نویس‌های</strong> زبان‌های دیگه که می‌خوان به پایتون مهاجرت کنن.</li>
#         <li>هر کسی که علاقه‌منده وارد حوزه‌هایی مثل <strong>توسعه وب، تحلیل داده، اتوماسیون یا هوش مصنوعی</strong> بشه.</li>
#       </ul>
#       <img style="width: 40vw; height: auto; display: block; margin: 15px auto; border-radius: 8px;" src="../../images/who_is_this_course_for.jpg" alt="این دوره برای چه کسانی است؟">
#     </div>
#     <div class="card purple">
#       <h3>روش آموزش ما چطوریه؟</h3>
#       <ul>
#         <li>هر درس در قالب یک فایل <strong>ژوپیتر نوت‌بوک (Jupyter Notebook)</strong> تمیز و تعاملی ارائه می‌شه.</li>
#         <li>مفاهیم با استفاده از مثال‌های واقعی و پیاده‌سازی‌های ساده توضیح داده شدن.</li>
#         <li>تمرین‌های پایان هر بخش به تثبیت چیزهایی که یاد گرفتی کمک می‌کنن.</li>
#         <li>دوره یک مسیر مشخص و قدم‌به‌قدم رو دنبال می‌کنه تا گیج نشی.</li>
#       </ul>
#       <div class="note">
#         <strong>💡 نکته طلایی:</strong> پوشه هر درس رو توی VS Code باز کن و همزمان با دیدن ویدیو، کدها رو خودت هم اجرا کن. برنامه‌نویسی فقط با دیدن یاد گرفته نمی‌شه!
#       </div>
#     </div>
#     <div class="card gray">
#       <h3>📚 منابع پیشنهادی برای یادگیری عمیق‌تر</h3>
#       <p>برای کسانی که دوست دارن بعد از این دوره عمیق‌تر وارد دنیای پایتون بشن، خوندن این ۳ کتاب سطح جهانی رو پیشنهاد می‌کنم:</p>
#       <div class="book-grid">
#         <div class="book-item">
#           <img src="../../images/crash_course.jpg" alt="کتاب Python Crash Course">
#           <span>Python Crash Course</span>
#         </div>
#         <div class="book-item">
#           <img src="../../images/fluent_python.jpg" alt="کتاب Fluent Python">
#           <span>Fluent Python</span>
#         </div>
#         <div class="book-item">
#           <img src="../../images/automate_boring.jpg" alt="کتاب Automate the Boring Stuff">
#           <span>Automate the Boring Stuff</span>
#         </div>
#       </div>
#     </div>
#     <p style="text-align:center; margin-top:1.5rem;">
#       <a href="01 آشنایی با برنامه‌نویسی پایتون.ipynb" style="
#           display:inline-block;
#           background-color:#29b6f6;
#           color:#000;
#           padding:0.8rem 1.5rem;
#           border-radius:8px;
#           text-decoration:none;
#           font-weight:bold;
#           font-size: 1.1rem;
#           transition: transform 0.3s, background-color 0.3s;
#           box-shadow: 0 4px 10px rgba(41, 182, 246, 0.3);
#       " onmouseover="this.style.backgroundColor='#66bb6a'; this.style.transform='scale(1.05)';" onmouseout="this.style.backgroundColor='#29b6f6'; this.style.transform='scale(1)';">
#         🚀 ورود به درس اول
#       </a>
#     </p>
#
#   </div>
# </div>
