# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   /* Global Settings */
#   * { box-sizing: border-box; }
#
#   /* Section Card Style */
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   /* Typography */
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#
#   /* Inner Cards */
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent; /* Changed to right for RTL */
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#
#   /* Fix for Last Child Margin */
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   /* Images */
#   img { display: block; max-width: 40vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#
#   /* TOC Style */
#   .toc-card ul { list-style-type: none; padding-right: 1rem; padding-left: 0; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; font-weight: 500; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#   .toc-card ul ul { padding-right: 1.5rem; margin-top: 0.5rem; list-style-type: circle; }
#   .toc-card ul ul li a { color: #dcdcdc; font-weight: normal; }
#
#   /* Accent Colors (Right Borders) */
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#   .pink { border-right-color: #f06292; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     .card { padding: 1rem; width: 100%; }
#     img { max-width: 85vw; }
#   }
# </style>
#
# <!-- Title Section -->
# <div class="section-card">
#   <h1>روابط بین اشیاء در پایتون 🤝</h1>
# </div>
#
# <!-- Intro -->
# <div class="section-card">
#   <h2>درک تعاملات (Interactions)</h2>
#   <div class="container">
#     <div class="card blue">
#       <h3>چرا این موضوع مهم است؟</h3>
#       <p>کلاس‌ها به تنهایی و در انزوا کار نمی‌کنند. درک نحوه ارتباط آن‌ها با یکدیگر (انجمن، تجمیع، ترکیب، ارث‌بری) کلید اصلی در طراحی سیستم‌های نرم‌افزاری پایدار و قدرتمند است.</p>
#     </div>
#     <div class="card purple">
#       <h3>۴ نوع اصلی روابط بین اشیاء</h3>
#       <ul>
#         <li><strong>انجمن (Association):</strong> رابطه «استفاده می‌کند از» (Uses-a). یک رابطه سست و ضعیف. (مثال: دکتر از گوشی پزشکی استفاده می‌کند).</li>
#         <li><strong>تجمیع (Aggregation):</strong> رابطه «دارد» (Has-a). مالکیت ضعیف. (مثال: تیم دارای بازیکنانی است).</li>
#         <li><strong>ترکیب (Composition):</strong> رابطه «بخشی از» (Part-of). مالکیت بسیار قوی. (مثال: خانه از اتاق‌هایی تشکیل شده است).</li>
#         <li><strong>ارث‌بری (Inheritance):</strong> رابطه «نوعی از است» (Is-a). سلسله‌مراتب. (مثال: پرنده نوعی حیوان است).</li>
#       </ul>
#       <img src="../../images/object-relationships.png" alt="انواع روابط">
#     </div>
#   </div>
# </div>
#
# <!-- Table of Contents -->
# <div class="section-card" id="toc0_">
#   <h2>فهرست مطالب</h2>
#   <div class="container">
#     <div class="card toc-card blue">
#       <h3>دسترسی سریع</h3>
#       <ul>
#         <li><a href="#toc1_">۱. انجمن (Association)</a></li>
#         <li><a href="#toc2_">۲. تجمیع (Aggregation)</a></li>
#         <li><a href="#toc3_">۳. ترکیب (Composition)</a></li>
#         <li><a href="#toc4_">۴. ارث‌بری (Inheritance)</a></li>
#         <li><a href="#toc5_">۵. راهنمای کاربردی: کِی از کدام استفاده کنیم؟</a></li>
#         <li><a href="#toc7_">۶. تمرین عملی: شبیه‌سازی باغ‌وحش</a></li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <!-- Association Section -->
# <div class="section-card" id="toc1_">
#   <h2>۱. انجمن (Association)</h2>
#   <div class="container">
#     <div class="card green">
#       <h3>مفهوم</h3>
#       <p>در این الگو، اشیاء با یکدیگر تعامل دارند اما کاملاً مستقل از هم باقی می‌مانند. هیچ مالکیتی بین آن‌ها وجود ندارد.</p>
#       <img src="../../images/association.png" alt="Association">
#     </div>
#     <div class="card green">
#       <h3>مثال ۱: پزشک و گوشی پزشکی</h3>
#       <img src="../../images/doctor.png" alt="Doctor">
#       <p>دکتر از گوشی پزشکی استفاده می‌کند، اما هر دوی آن‌ها می‌توانند به صورت کاملاً مستقل وجود داشته باشند.</p>
#     </div>
#   </div>
# </div>

# %%
class Stethoscope:
    def __init__(self, brand):
        self.brand = brand

    def use(self):
        print(f"استفاده از گوشی پزشکی برند {self.brand}.")

class Doctor:
    def __init__(self, name):
        self.name = name

    def check_patient(self, stethoscope):
        print(f"دکتر {self.name} در حال معاینه بیمار است.")
        stethoscope.use()

# %%
# مثال استفاده
my_stethoscope = Stethoscope("Littmann")
dr_jones = Doctor("جونز")

# %%
dr_jones.check_patient(my_stethoscope)

# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1, h2 { text-align: center; color: #ffffff; font-weight: 700; margin-bottom: 1.5rem; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   img { display: block; max-width: 40vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#   .green { border-right-color: #66bb6a; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { padding: 1rem; width: 100%; } img { max-width: 85vw; } }
# </style>
#
# <div class="section-card">
#   <div class="container">
#     <div class="card green">
#       <h3>مثال ۲: صاحب و سگ</h3>
#       <p>یک شخص می‌تواند صاحب چند سگ باشد. سگ‌ها بخشی از وجود شخص نیستند، فقط با او رابطه دارند.</p>
#     </div>
#   </div>
# </div>

# %%
class Dog:
    def __init__(self, name):
        self.name = name

    def play(self):
        print(f"{self.name} در حال بازی کردن است.")

class Owner:
    def __init__(self, name):
        self.name = name
        self.dogs = []  # می‌تواند چندین شیء از کلاس سگ را نگه دارد

    def add_dog(self, dog):
        self.dogs.append(dog)

    def play_with_dogs(self):
        print(f"{self.name} در حال بازی با سگ‌هایش است.")
        for dog in self.dogs:
            dog.play()

# %%
# مثال استفاده
buddy = Dog("بادی")
rover = Dog("روور")
jane = Owner("جین")

# %%
jane.add_dog(buddy)
jane.add_dog(rover)

# %%
jane.play_with_dogs()

# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1, h2 { text-align: center; color: #ffffff; font-weight: 700; margin-bottom: 1.5rem; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   img { display: block; max-width: 40vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .orange { border-right-color: #ffa726; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { padding: 1rem; width: 100%; } img { max-width: 85vw; } }
# </style>
#
# <div class="section-card" id="toc2_">
#   <h2>۲. تجمیع (Aggregation)</h2>
#   <div class="container">
#     <div class="card orange">
#       <h3>مفهوم</h3>
#       <p>یک رابطه «کل و جزء» است. مالکیت در اینجا ضعیف است، یعنی <strong>جزء می‌تواند مستقل از کل وجود داشته باشد.</strong></p>
#       <img src="../../images/aggregation.png" alt="Aggregation">
#     </div>
#     <div class="card orange">
#       <h3>مثال: تیم و بازیکنان</h3>
#       <p>یک تیم متشکل از چندین بازیکن است. اگر تیم منحل شود (از بین برود)، بازیکنان همچنان وجود دارند و نابود نمی‌شوند.</p>
#     </div>
#   </div>
# </div>

# %%
class Player:
    def __init__(self, name):
        self.name = name

class Team:
    def __init__(self, name):
        self.name = name
        self.players = []  # اینجا رابطه تجمیع (Aggregation) برقرار می‌شود

    def add_player(self, player):
        self.players.append(player)

    def remove_player(self, player):
        self.players.remove(player)

# %%
# چرخه حیات (Lifecycle) اشیاء بازیکن به شیء تیم وابسته نیست
player1 = Player("Alex")
team = Team("Sharks")
team.add_player(player1)
# در اینجا، player1 می‌تواند عضو تیم دیگری شود یا اصلاً تیمی نداشته باشد، که این نشان‌دهنده استقلال اوست.

# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1, h2 { text-align: center; color: #ffffff; font-weight: 700; margin-bottom: 1.5rem; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .orange { border-right-color: #ffa726; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { padding: 1rem; width: 100%; } }
# </style>
#
# <div class="section-card">
#   <div class="container">
#     <div class="card orange">
#       <h3>مثال ۲: سگ و قلاده</h3>
#       <p>یک سگ می‌تواند قلاده بپوشد، اما این قلاده می‌تواند باز شده و به سگ دیگری بسته شود (مستقل از هم هستند).</p>
#     </div>
#   </div>
# </div>

# %%
class Collar:
    def __init__(self, color):
        self.color = color

class Dog:
    def __init__(self, name):
        self.name = name
        self.collar = None  # در ابتدا سگ ممکن است قلاده نداشته باشد

    def add_collar(self, collar):
        self.collar = collar

    def remove_collar(self):
        self.collar = None

# %%
# ساخت شیء قلاده
blue_collar = Collar("آبی")

# %%
# ساخت شیء سگ و متصل کردن قلاده به آن
buddy = Dog("بادی")
buddy.add_collar(blue_collar)

# %%
# سگ حالا قلاده دارد (رابطه تجمیع برقرار است)
# می‌توانیم قلاده را باز کنیم، که استقلال آن را نشان می‌دهد
buddy.remove_collar()

# %%
# قلاده هنوز در سیستم وجود دارد و می‌تواند برای سگ دیگری استفاده شود
rover = Dog("روور")
rover.add_collar(blue_collar)

# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1, h2 { text-align: center; color: #ffffff; font-weight: 700; margin-bottom: 1.5rem; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   img { display: block; max-width: 40vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .red { border-right-color: #ef5350; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { padding: 1rem; width: 100%; } img { max-width: 85vw; } }
# </style>
#
# <div class="section-card" id="toc3_">
#   <h2>۳. ترکیب (Composition)</h2>
#   <div class="container">
#     <div class="card red">
#       <h3>مفهوم</h3>
#       <p>یک رابطه قدرتمندِ «کل و جزء». در اینجا <strong>مالکیت بسیار قوی</strong> است. اگر شیءِ «کُل» نابود شود، شیءِ «جزء» نیز از بین می‌رود و به تنهایی معنایی ندارد.</p>
#       <img src="../../images/composition.png" alt="Composition">
#     </div>
#     <div class="card red">
#       <h3>تفاوت با تجمیع (Aggregation)</h3>
#       <p><strong>تجمیع:</strong> سست و ضعیف. مالکیت اشتراکی. (مثال: خانه و ساکنان آن - اگر خانه خراب شود، آدم‌ها زنده می‌مانند)<br>
#       <strong>ترکیب:</strong> قوی. مالکیت انحصاری. (مثال: خانه و اتاق‌های آن - اگر خانه خراب شود، اتاق‌ها هم از بین می‌روند)</p>
#     </div>
#     <div class="card red">
#       <h3>مثال ۱: کامپیوتر و قطعات آن</h3>
#       <p>پردازنده (CPU)، رم و هارد دیسک، اجزای داخلی یک کامپیوتر خاص هستند. آن‌ها <strong>همراه با</strong> کامپیوتر ساخته می‌شوند.</p>
#     </div>
#   </div>
# </div>

# %%
class Processor:
    def __init__(self, name):
        self.name = name

# %%
class Memory:
    def __init__(self, size):
        self.size = size

# %%
class HardDrive:
    def __init__(self, capacity):
        self.capacity = capacity

# %%
class Computer:
    def __init__(self):
        self.processor = Processor("Intel i7")
        self.memory = Memory(16)  # بر حسب گیگابایت
        self.hard_drive = HardDrive(1)  # بر حسب ترابایت

    def describe(self):
        print(f"کامپیوتری با پردازنده {self.processor.name}، {self.memory.size} گیگابایت رم، و {self.hard_drive.capacity} ترابایت حافظه.")

# %%
# وقتی یک نمونه از کامپیوتر ساخته می‌شود، قطعات آن نیز همزمان ساخته می‌شوند و عمرشان به کامپیوتر وابسته است.
my_computer = Computer()
my_computer.describe()
# از بین رفتن 'my_computer' به معنای از بین رفتن قطعات آن نیز هست (رابطه قوی کل و جزء).

# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1, h2 { text-align: center; color: #ffffff; font-weight: 700; margin-bottom: 1.5rem; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .red { border-right-color: #ef5350; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { padding: 1rem; width: 100%; } }
# </style>
#
# <div class="section-card">
#   <div class="container">
#     <div class="card red">
#       <h3>مثال ۲: سگ و دُم</h3>
#       <p>دُم بخش جدایی‌ناپذیر یک سگ است. یک دُم به تنهایی (بدون سگ) وجودِ معناداری ندارد.</p>
#     </div>
#   </div>
# </div>

# %%
class Tail:
    def __init__(self, length):
        self.length = length  # طول بر حسب سانتی‌متر

    def wag(self):
        print("دُم در حال تکان خوردن است.")

# %%
class Dog:
    def __init__(self, name):
        self.name = name
        self.tail = Tail(20)  # فرض می‌کنیم هر سگ یک دُم ۲۰ سانتی‌متری دارد

    def wag_tail(self):
        print(f"{self.name} خوشحال است!")
        self.tail.wag()

# %%
# با ایجاد شیء سگ، دُم نیز به عنوان بخشی لاینفک از او ساخته می‌شود.
buddy = Dog("بادی")
buddy.wag_tail()
# در اینجا، دُم بادی کاملاً به او وابسته است و مفهوم «ترکیب» (Composition) را نشان می‌دهد.

# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1, h2 { text-align: center; color: #ffffff; font-weight: 700; margin-bottom: 1.5rem; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   img { display: block; max-width: 40vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .purple { border-right-color: #ba68c8; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { padding: 1rem; width: 100%; } img { max-width: 85vw; } }
# </style>
#
# <div class="section-card" id="toc4_">
#   <h2>۴. ارث‌بری (Inheritance)</h2>
#   <div class="container">
#     <div class="card purple">
#       <h3>مفهوم</h3>
#       <p>رابطه «نوعی از است» (Is-a). یک کلاس جدید از کلاسی که قبلاً وجود داشته مشتق می‌شود و ویژگی‌ها و رفتارهای آن را به ارث می‌برد.</p>
#       <img src="../../images/inheritance.png" alt="Inheritance">
#     </div>
#     <div class="card purple">
#       <h3>انواع ارث‌بری</h3>
#       <ul>
#         <li><strong>یگانه (Single):</strong> یک والد.</li>
#         <li><strong>چندگانه (Multiple):</strong> چند والد مختلف.</li>
#         <li><strong>چندسطحی (Multilevel):</strong> پدربزرگ -> پدر -> فرزند.</li>
#         <li><strong>سلسله‌مراتبی (Hierarchical):</strong> یک والد، چندین فرزند.</li>
#       </ul>
#       <img src="../../images/inheritance-types.png" style="display: block; max-width: 50vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1);" alt="Inheritance Types">
#     </div>
#     <div class="card purple">
#       <h3>مثال: حیوان خانگی و سگ</h3>
#       <p>یک سگ، <strong>نوعی</strong> حیوان خانگی (Pet) است.</p>
#     </div>
#   </div>
# </div>

# %%
class Pet:
    def __init__(self, name):
        self.name = name

    def show_affection(self):
        print(f"{self.name} ابراز علاقه می‌کند.")

class Dog(Pet):  # کلاس سگ از حیوان خانگی ارث می‌برد
    def __init__(self, name, breed):
        super().__init__(name)  # فراخوانی سازنده کلاس والد
        self.breed = breed

    def bark(self):
        print(f"{self.name} که از نژاد {self.breed} است، پارس می‌کند.")

# %%
# استفاده
my_pet = Pet("بادی")
my_pet.show_affection()

# %%
my_dog = Dog("مکس", "گلدن رتریور")

# %%
my_dog.show_affection()  # متد به ارث برده شده

# %%
my_dog.bark()  # متد اختصاصی کلاس سگ

# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1, h2 { text-align: center; color: #ffffff; font-weight: 700; margin-bottom: 1.5rem; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .red { border-right-color: #ef5350; }
#   .purple { border-right-color: #ba68c8; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { padding: 1rem; width: 100%; } }
# </style>
#
# <div class="section-card" id="toc5_">
#   <h2>۵. راهنمای کاربردی: کِی از کدام استفاده کنیم؟</h2>
#   <div class="container">
#     <div class="card blue">
#       <h3>تقلب‌نامه (Cheat Sheet)</h3>
#       <ul>
#         <li><strong>ارث‌بری:</strong> برای روابط «نوعی از است» (Is-a). (ماشین نوعی وسیله نقلیه است)</li>
#         <li><strong>انجمن:</strong> برای روابط «استفاده می‌کند از» (Uses-a). (مشتری از روش پرداخت استفاده می‌کند)</li>
#         <li><strong>تجمیع:</strong> برای روابط «دارد» (Has-a) به‌صورت <strong>مستقل</strong>. (ایرلاین هواپیماهایی دارد)</li>
#         <li><strong>ترکیب:</strong> برای روابط «دارد» (Has-a) به‌صورت <strong>وابسته</strong>. (کتاب صفحاتی دارد)</li>
#       </ul>
#     </div>
#     <div class="card green">
#       <h3>بهترین روش‌ها (Best Practices)</h3>
#       <ul>
#         <li>برای انعطاف‌پذیری بیشتر، <strong>استفاده از ترکیب را به ارث‌بری ترجیح دهید</strong> (Composition over Inheritance).</li>
#         <li>وابستگی‌ها (Coupling) را پایین نگه دارید (اشیاء باید تا حد امکان مستقل باشند).</li>
#         <li>از ایجاد زنجیره‌های ارث‌بری طولانی و عمیق خودداری کنید.</li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc7_">
#   <h2>۶. تمرین عملی: شبیه‌سازی باغ‌وحش</h2>
#   <div class="container">
#     <div class="card red">
#       <h3>وظیفه شما</h3>
#       <ol>
#         <li><strong>انجمن (Association):</strong> محیط‌بان و ابزارها.</li>
#         <li><strong>تجمیع (Aggregation):</strong> زیستگاه و حیوانات.</li>
#         <li><strong>ترکیب (Composition):</strong> باغ‌وحش و زیستگاه‌ها.</li>
#         <li><strong>ارث‌بری (Inheritance):</strong> گونه‌های مختلف و حیوانات.</li>
#       </ol>
#     </div>
#     <div class="card purple">
#       <h3>راه حل</h3>
#       <p>در ادامه یک راه حل کامل پایتونی که تمام این روابط را نشان می‌دهد، آورده شده است.</p>
#     </div>
#   </div>
# </div>

# %%
# تسک ۱: انجمن (Association) - محیط‌بان و ابزارها
class Tool:
    def __init__(self, name):
        self.name = name

    def use(self):
        print(f"در حال استفاده از ابزار: {self.name}")

class Zookeeper:
    def __init__(self, name):
        self.name = name

    def use_tool(self, tool):
        print(f"{self.name} اکنون آماده است: ")
        tool.use()

# تسک ۲: تجمیع (Aggregation) - زیستگاه و حیوانات
class Animal:
    def __init__(self, name):
        self.name = name

class Habitat:
    def __init__(self):
        self.animals = []

    def add_animal(self, animal):
        self.animals.append(animal)

    def remove_animal(self, animal):
        self.animals.remove(animal)

# تسک ۳: ترکیب (Composition) - باغ‌وحش و زیستگاه‌ها
class Zoo:
    def __init__(self):
        self.habitats = []

    def add_habitat(self, habitat):
        self.habitats.append(habitat)

    def __del__(self):
        print("باغ‌وحش در حال بسته شدن است و تمام زیستگاه‌ها حذف می‌شوند.")
        del self.habitats

# تسک ۴: ارث‌بری (Inheritance) - گونه‌های مختلف و حیوانات
class Lion(Animal):
    def roar(self):
        print(f"{self.name} با صدای بلند غرش می‌کند!")

class Penguin(Animal):
    def swim(self):
        print(f"{self.name} با زیبایی شنا می‌کند.")

# تسک ۵: پیاده‌سازی کاربردی - تصمیم‌گیری در مورد نوع رابطه
# از انجمن استفاده کردیم چون سابقه پزشکی حیوان نباید فقط محدود به خود حیوان یا محیط‌بان باشد
class VeterinaryCareRecord:
    def __init__(self, animal, description):
        self.animal = animal
        self.description = description

# نمایش عملیات
broom = Tool("جارو")
zookeeper_jane = Zookeeper("جِین")
zookeeper_jane.use_tool(broom)

lion_habitat = Habitat()
leo = Animal("لئو (شیر)")
lion_habitat.add_animal(leo)

alex = Lion("الکس")
marty = Penguin("مارتی")
alex.roar()
marty.swim()

leo_care_record = VeterinaryCareRecord(leo, "واکسیناسیون سالانه.")
print(f"{leo_care_record.animal.name} یک سابقه پزشکی برای: {leo_care_record.description} دارد.")

# %% [markdown]
# <style>
#   /* Import Persian Font */
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease; border-right: 4px solid transparent; }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .green { border-right-color: #66bb6a; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { padding: 1rem; width: 100%; } }
# </style>
#
# <div class="section-card">
#   <div class="container">
#     <div class="card green">
#       <p>این کد با موفقیت تمام ۴ نوع رابطه بین اشیاء را در قالب یک سناریوی واحد به نمایش می‌گذارد.</p>
#     </div>
#   </div>
# </div>
