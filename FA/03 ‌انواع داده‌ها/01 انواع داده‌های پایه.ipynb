# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; font-family: 'Vazirmatn', sans-serif; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; transition: transform 0.3s ease; }
#   .card:hover { transform: translateY(-5px); }
#   .green { border-right-color: #66bb6a; }
#   .blue { border-right-color: #29b6f6; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h1 { font-size: 2rem; } .card { width: 100%; padding: 1rem; } }
# </style>
#
# <div class="section-card">
# <h1>انواع داده‌های پایه (Basic Data Types) 🧱</h1>
# </div>
# <div class="section-card">
#   <div class="container">
#     <div class="card green">
#       <p>در برنامه‌نویسی، «انواع داده» (Data Types) یکی از مفاهیم بنیادی است که داده‌ها را دسته‌بندی می‌کند. نوع داده مشخص می‌کند که یک متغیر چه مقادیر و چه عملیاتی را می‌تواند بپذیرد.</p>
#       <p style="margin-bottom:0;">در این درس، با انواع داده‌های اصلی پایتون آشنا می‌شویم: <strong>اعداد</strong>، <strong>رشته‌ها</strong> و <strong>مقادیر بولی (Boolean)</strong>.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   /* Global Settings */
#   * { box-sizing: border-box; }
#
#   /* Section Card Style */
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#     direction: rtl; font-family: 'Vazirmatn', sans-serif;
#   }
#
#   /* Typography */
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul, ol { padding-right: 1.25rem; padding-left: 0; margin-bottom: 0.75rem; }
#   strong { color: #ffffff; }
#
#   /* Inner Cards */
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-right: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#
#   /* Fix for Last Child Margin */
#   .container > .card:last-child { margin-bottom: 2rem; }
#
#   /* Images */
#   img { display: block; max-width: 50vw; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#
#   /* TOC Style */
#   .toc-card ul { list-style-type: none; padding-right: 1rem; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; font-weight: 500; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#   .toc-card ul ul { padding-right: 1.5rem; margin-top: 0.5rem; list-style-type: circle; }
#   .toc-card ul ul li a { color: #dcdcdc; font-weight: normal; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.95rem; direction: ltr; display: inline-block; }
#
#   /* Accent Colors */
#   .blue { border-right-color: #29b6f6; }
#   .green { border-right-color: #66bb6a; }
#   .orange { border-right-color: #ffa726; }
#   .purple { border-right-color: #ba68c8; }
#   .red { border-right-color: #ef5350; }
#   .pink { border-right-color: #f06292; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     .section-card h2 { font-size: 1.4rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
# <div class="section-card">
#   <h2>فهرست مطالب</h2>
#   <div class="container">
#     <div class="card blue toc-card">
#       <h3>دسترسی سریع</h3>
#       <ul>
#         <li><a href="#toc1_">۱. اعداد صحیح (Integers)</a>
#            <ul><li><a href="#toc1_1_">بدون محدودیت طول</a></li><li><a href="#toc1_2_">مبناهای عددی (Number Bases)</a></li></ul>
#         </li>
#         <li><a href="#toc2_">۲. اعداد اعشاری (Floating-Point)</a></li>
#         <li><a href="#toc4_">۳. رشته‌ها (Strings)</a></li>
#         <li><a href="#toc5_">۴. نوع داده بولی (Boolean)</a></li>
#         <li><a href="#toc6_">جمع‌بندی</a></li>
#       </ul>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .orange { border-right-color: #ffa726; }
#   p { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc1_">
#   <h2>۱. اعداد صحیح (Integers)</h2>
#   <div class="container">
#     <div class="card orange">
#       <p>قبل از اینکه وارد جزئیات فنی شویم، بیایید با چند مثال ساده شروع کنیم. فرض کنید شما ۵ عدد سیب دارید:</p>
#     </div>
#   </div>
# </div>

# %%
10
# Out:
# 10

# %%
15
# Out:
# 15

# %%
-18
# Out:
# -18

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .orange { border-right-color: #ffa726; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card orange" id="toc1_1_">
#       <h3>بدون محدودیت طول (No Real Length Limit)</h3>
#       <p>اعداد صحیح (با نوع داده <code>int</code>) اعداد کامل و بدون اعشار هستند. یکی از ویژگی‌های جذاب پایتون این است که اعداد صحیح می‌توانند <strong>بسیار بزرگ</strong> باشند و تنها محدودیت آن‌ها، میزان حافظه (RAM) سیستم شماست.</p>
#     </div>
#   </div>
# </div>

# %%
123123123123123123123123123123123123123123123123 + 1
# Out:
# 123123123123123123123123123123123123123123123124

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: 700; border-bottom: 1px solid rgba(255,255,255,0.1); padding-bottom: 0.5rem; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .orange { border-right-color: #ffa726; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.5rem; }
#   ul { padding-right: 1.25rem; padding-left: 0; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="card orange" id="toc1_2_">
#       <h3>مبناهای عددی (Number Bases)</h3>
#       <p>اعداد به طور پیش‌فرض در مبنای ۱۰ (Decimal) هستند، اما می‌توانید با استفاده از پیشوندها، آن‌ها را در مبناهای دیگر بنویسید:</p>
#       <ul>
#         <li><strong>باینری (مبنای ۲):</strong> پیشوند <code>0b</code> یا <code>0B</code></li>
#         <li><strong>اوکتال (مبنای ۸):</strong> پیشوند <code>0o</code> یا <code>0O</code></li>
#         <li><strong>هگزادسیمال (مبنای ۱۶):</strong> پیشوند <code>0x</code> یا <code>0X</code></li>
#       </ul>
#     </div>
#   </div>
# </div>

# %%
0b10
# Out:
# 2

# %%
0o10
# Out:
# 8

# %%
0x10
# Out:
# 16

# %%
type(10)
# Out:
# int

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   h1 { width: 100%; text-align: center; color: #ffffff; font-size: 2.8rem; margin-bottom: 1.5rem; font-family: 'Vazirmatn', sans-serif; letter-spacing: 1px; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-family: 'Vazirmatn', sans-serif; letter-spacing: 1px; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: bold; font-family: 'Vazirmatn', sans-serif; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .card.orange { border-right-color: #ffa726; }
#   p, li { color: #dcdcdc; font-size: 0.95rem; line-height: 1.5; font-family: 'Vazirmatn', sans-serif; margin-bottom: 0.75rem; }
#   ul { padding-right: 1.25rem; }
#   blockquote { border-right: 3px solid #66bb6a; padding-right: 1rem; margin-right: 0; color: #f0f0f0; font-style: italic; }
#   .note {
#     background-color: #fdd835;
#     color: #000;
#     padding: 1rem;
#     border-radius: 6px;
#     margin-top: 1.25rem;
#     font-style: italic;
#     font-size: 0.95rem;
#     font-family: 'Vazirmatn', sans-serif;
#     width: 90vw;
#     margin: 1.25rem auto 0;
#   }
#   .container > .note:last-child { margin-bottom: 2rem; }
#   code { background: rgba(0,0,0,0.1); padding: 2px 6px; border-radius: 4px; color: #000; font-family: monospace; direction: ltr; display: inline-block; font-weight: bold; }
#   @media (max-width: 768px) { h1 { font-size: 2rem; } .section-card { padding: 1.25rem; } .card { width: 100%; padding: 1rem; margin: 0 auto 1rem; } .section-card h2 { font-size: 1.4rem; } .card h3 { font-size: 1.2rem; } p, li { font-size: 0.9rem; }.note {
#       width: 100%;
#     } .note {
#       padding: 0.75rem;
#     }}
# </style>
# <div class="section-card">
#   <div class="container">
#       <div class="note">
#        تابع <code style="background-color:black; color: #ffab40;">type()</code> یک ابزار داخلی پایتون است که نوع داده‌ی یک آبجکت را برمی‌گرداند. این تابع برای چک کردن داده‌ها و دیباگ کردن بسیار کاربردی است، اما درک عمیق نحوه کار آن در این مرحله ضروری نیست.
#     </div>
#   </div>
# </div>

# %%
type(0b10)
# Out:
# int

# %%
type(0o10)  # Output: <class 'int'>
# Out:
# int

# %%
type(0x10)  # Output: <class 'int'>
# Out:
# int

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .purple { border-right-color: #ba68c8; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc2_">
#   <h2>۲. اعداد اعشاری (Floating-Point Numbers)</h2>
#   <div class="container">
#     <div class="card purple">
#       <p>اعداد اعشاری (یا Floats) اعدادی هستند که دارای نقطه اعشار می‌باشند. نوع داده آن‌ها <code>float</code> است و می‌توانند به صورت علمی نیز نوشته شوند (مثلاً <code>.4e7</code>).</p>
#       <p>در پایتون، اعداد اعشاری معمولاً ۶۴-بیتی هستند (طبق استاندارد IEEE 754). این یعنی محدودیت‌هایی در دقت و بزرگی آن‌ها وجود دارد. هر عددی بزرگتر از تقریبی 1.8 × 10<sup>308</sup> به عنوان بی‌نهایت (<code>inf</code>) در نظر گرفته می‌شود.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# **نمایش‌های مختلف اعداد اعشاری:**

# %%
4.2
# Out:
# 4.2

# %%
type(4.2)
# Out:
# float

# %%
4.
# Out:
# 4.0

# %%
.2
# Out:
# 0.2

# %%
.4e7
# Out:
# 4000000.0

# %%
type(.4e7)
# Out:
# float

# %%
4.2e-4
# Out:
# 0.00042

# %% [markdown]
# **حداکثر مقدار ممکن برای اعداد اعشاری:**

# %%
1.79e308
# Out:
# 1.79e+308

# %% [markdown]
# **هر عددی بزرگتر از $1.8 \times 10 ^ {308}$ بی‌نهایت در نظر گرفته می‌شود:**

# %%
1.8e308
# Out:
# inf

# %% [markdown]
# **حداقل مقدار ممکن برای اعداد اعشاری:**

# %%
5e-324
# Out:
# 5e-324

# %% [markdown]
# **هر عددی کوچکتر از $5.0 \times 10 ^ {-324}$ صفر در نظر گرفته می‌شود:**

# %%
1e-325
# Out:
# 0.0

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   h1 { width: 100%; text-align: center; color: #ffffff; font-size: 2.8rem; margin-bottom: 1.5rem; font-family: 'Vazirmatn', sans-serif; letter-spacing: 1px; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-family: 'Vazirmatn', sans-serif; letter-spacing: 1px; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: bold; font-family: 'Vazirmatn', sans-serif; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .container > .card:last-child { margin-bottom: 2rem; }
#   .card.orange { border-right-color: #ffa726; }
#   p, li { color: #dcdcdc; font-size: 0.95rem; line-height: 1.5; font-family: 'Vazirmatn', sans-serif; margin-bottom: 0.75rem; }
#   ul { padding-right: 1.25rem; }
#   blockquote { border-right: 3px solid #66bb6a; padding-right: 1rem; margin-right: 0; color: #f0f0f0; font-style: italic; }
#   .note {
#     background-color: #fdd835;
#     color: #000;
#     padding: 1rem;
#     border-radius: 6px;
#     margin-top: 1.25rem;
#     font-style: italic;
#     font-size: 0.95rem;
#     font-family: 'Vazirmatn', sans-serif;
#     width: 90vw;
#     margin: 1.25rem auto 0;
#   }
#   .container > .note:last-child { margin-bottom: 2rem; }
#   code { background: rgba(0,0,0,0.1); padding: 2px 6px; border-radius: 4px; color: #000; font-family: monospace; direction: ltr; display: inline-block; font-weight: bold; }
#   @media (max-width: 768px) { h1 { font-size: 2rem; } .section-card { padding: 1.25rem; } .card { width: 100%; padding: 1rem; margin: 0 auto 1rem; } .section-card h2 { font-size: 1.4rem; } .card h3 { font-size: 1.2rem; } p, li { font-size: 0.9rem; }.note {
#       width: 100%;
#     } .note {
#       padding: 0.75rem;
#     }}
# </style>
# <div class="section-card">
#   <div class="container">
#     <div class="note">
#       <strong>دقت کنید:</strong> اعداد اعشاری در کامپیوتر به صورت باینری ذخیره می‌شوند و این یعنی برخی اعداد دقیق نیستند. به همین دلیل ممکن است خطاهای بسیار کوچکی در محاسبات ببینید. مثلاً <code style="background-color:black; color: #ffab40;">1.1 + 2.2</code> دقیقاً برابر با <code style="background-color:black; color: #ffab40;">3.3</code> نمی‌شود.
#     </div>
#   </div>
# </div>

# %%
# ببینید که چگونه تبدیل از دهدهی به باینری دقیق نیست
1.1 + 2.2 == 3.3
# Out:
# False

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .green { border-right-color: #66bb6a; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc4_">
#   <h2>۳. رشته‌ها (Strings)</h2>
#   <div class="container">
#     <div class="card green">
#       <p>رشته‌ها (نوع داده <code>str</code>) دنباله‌ای از کاراکترها هستند. آن‌ها را می‌توان با کوتیشن تکی (<code>'</code>) یا دوتایی (<code>"</code>) ایجاد کرد. اگر بخواهید داخل متن از یک نوع کوتیشن استفاده کنید، باید کل رشته را با نوع دیگر محصور کنید.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# **نمایش ساده رشته‌ها**

# %%
"I am a string."
# Out:
# 'I am a string.'

# %%
type("I am a string.")
# Out:
# str

# %% [markdown]
# رشته‌ها در پایتون می‌توانند هر تعداد کاراکتر داشته باشند، حتی صفر (رشته خالی):

# %%
''
# Out:
# ''

# %% [markdown]
# **استفاده از کوتیشن در داخل متن**

# %%
"This string contains a single quote (') character."
# Out:
# "This string contains a single quote (') character."

# %%
'This string contains a double quote (") character.'
# Out:
# 'This string contains a double quote (") character.'

# %% [markdown]
# **غیرفعال کردن معنی خاص کوتیشن‌ها (با استفاده از بک‌اسلش)**

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .blue { border-right-color: #29b6f6; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc5_">
#   <h2>۴. نوع داده بولی (Boolean)</h2>
#   <div class="container">
#     <div class="card blue">
#       <p>نوع داده بولی یا <code>bool</code> تنها دو مقدار ممکن دارد: <code>True</code> (درست) و <code>False</code> (نادرست). این‌ها پایه و اساس منطق برنامه‌نویسی و تصمیم‌گیری‌ها هستند.</p>
#       <p style="margin-bottom:0;">در پایتون، عبارات می‌توانند از نظر منطقی ارزیابی شوند تا مشخص شود «درست» هستند یا «نادرست» (مثلاً رشته‌های غیرخالی درست در نظر گرفته می‌شوند و عدد ۰ نادرست).</p>
#     </div>
#   </div>
# </div>

# %%
type(True)
# Out:
# bool

# %% [markdown]
# <style>
#   @import url('https://fonts.googleapis.com/css2?family=Vazirmatn:wght@400;500;700&display=swap');
#   * { box-sizing: border-box; }
#   .section-card { background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70)); border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem; box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw; direction: rtl; font-family: 'Vazirmatn', sans-serif; }
#   h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-weight: 700; }
#   .container { display: flex; flex-direction: column; gap: 1.25rem; align-items: center; }
#   .card { background: linear-gradient(145deg, #24243e, #1e1e3a); border-radius: 12px; padding: 1.5rem; box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); border-right: 4px solid transparent; width: 90vw; margin: 0 auto 1.25rem; }
#   .orange { border-right-color: #ffa726; }
#   p, li { color: #dcdcdc; font-size: 1rem; line-height: 1.8; margin-bottom: 0.75rem; }
#   ul { padding-right: 1.25rem; padding-left: 0; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; direction: ltr; display: inline-block; }
#   @media (max-width: 768px) { .section-card { padding: 1.25rem; } h2 { font-size: 1.4rem; } .card { width: 100%; padding: 1rem; } }
# </style>
# <div class="section-card" id="toc6_">
#   <h2>جمع‌بندی</h2>
#   <div class="container">
#     <div class="card orange">
#       <p>ما انواع داده‌های اصلی پایتون را بررسی کردیم که پایه ساختارهای پیچیده‌تر هستند:</p>
#       <ul>
#          <li><strong>اعداد (int, float):</strong> برای داده‌های عددی استفاده می‌شوند؛ int برای اعداد صحیح و float برای اعشاری.</li>
#          <li><strong>رشته‌ها (str):</strong> برای داده‌های متنی استفاده می‌شوند و قابلیت‌های زیادی مثل کاراکترهای ویژه و متن‌های چندخطی دارند.</li>
#          <li><strong>بولی (bool):</strong> مقادیر <code>True</code> یا <code>False</code> را نگه می‌دارند و برای عملیات منطقی حیاتی هستند.</li>
#       </ul>
#       <p style="margin-bottom:0;">درک عمیق این انواع داده، اولین قدم برای نوشتن برنامه‌های قدرتمند و بدون خطا در پایتون است.</p>
#     </div>
#   </div>
# </div>
