# %% [markdown]
# <style>
#   /* Global Settings */
#   * { box-sizing: border-box; }
#
#   /* Section Card Style */
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#   }
#
#   /* Typography */
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-family: 'Poppins', sans-serif; letter-spacing: 1px; }
#   .container > .card:last-child {
#       margin-bottom: 2rem;
#     }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-family: 'Poppins', sans-serif; letter-spacing: 1px; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: bold; font-family: 'Segoe UI', sans-serif; }
#
#   p, li { color: #dcdcdc; font-size: 0.95rem; line-height: 1.6; font-family: 'Segoe UI', sans-serif; margin-bottom: 0.5rem; }
#   ul, ol { padding-left: 1.25rem; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.9rem; }
#   pre { background: #1a1a2e; padding: 1rem; border-radius: 8px; overflow-x: auto; margin-top: 10px; }
#
#   /* Inner Cards */
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-left: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#
#   /* Images */
#   img { display: block; max-width: 80%; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#
#   /* Note */
#   .note { background: #fdd835; color: #000; padding: 1rem; border-radius: 6px; margin-top: 1rem; font-style: italic; }
#
#   /* TOC */
#   .toc-card ul { list-style-type: none; padding-left: 0; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#
#   /* Colors */
#   .blue { border-left-color: #29b6f6; }
#   .green { border-left-color: #66bb6a; }
#   .orange { border-left-color: #ffa726; }
#   .purple { border-left-color: #ba68c8; }
#   .red { border-left-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h1>Getting the Course Code 📥</h1>
# </div>
#
# <div class="section-card" id="toc0_">
#   <h2>Table of Contents</h2>
#   <div class="container">
#     <div class="card toc-card blue">
#       <h3>Choose Your Method</h3>
#       <ul>
#         <li><a href="#toc1_">Method 1: Download ZIP (Easy & Fast)</a></li>
#         <li><a href="#toc2_">Method 2: Using Git (Professional & Updatable)</a></li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <!-- Method 1: ZIP -->
# <div class="section-card" id="toc1_">
#   <h2>Method 1: Using the Download Button</h2>
#   <div class="container">
#     <div class="card green">
#       <h3>Step 1: Download the ZIP</h3>
#       <ol>
#         <li>Navigate to the repository main page.</li>
#         <li>Click on the green <strong>Code</strong> button.</li>
#         <li>Select <strong>Download ZIP</strong>.</li>
#       </ol>
#       <img src="../../images/download-source-code.png" alt="Download ZIP">
#     </div>
#     <div class="card green">
#       <h3>Step 2: Extract & Open</h3>
#       <ol>
#         <li>Go to your Downloads folder and extract the ZIP file.</li>
#         <li>Open VS Code.</li>
#         <li><strong>Important:</strong> Go to <code>File > Open Folder...</code> and select the extracted folder.</li>
#         <li>Alternatively, use the terminal:</li>
#       </ol>
#       <pre><code>cd path/to/extracted/folder
# code .</code></pre>
#       <div class="note">
#         <strong>Note:</strong> If you want to update the files later, you will need to download and extract the ZIP file again.
#       </div>
#     </div>
#   </div>
# </div>
#
# <!-- Method 2: Git -->
# <div class="section-card" id="toc2_">
#   <h2>Method 2: Using Git (Recommended)</h2>
#   <div class="container">
#     <!-- Install Git -->
#     <div class="card orange">
#       <h3>Step 1: Install Git</h3>
#       <ul>
#         <li><strong>Windows:</strong> Download and install from <a href="https://git-scm.com/" style="color:#ffa726">git-scm.com</a>.</li>
#         <li><strong>macOS:</strong> Open terminal and type <code>git --version</code>. If not installed, it will prompt you.</li>
#         <li><strong>Linux (Debian/Ubuntu):</strong> Run <code>sudo apt install git</code>.</li>
#       </ul>
#     </div>
#     <!-- Clone Repo -->
#     <div class="card orange">
#       <h3>Step 2: Clone the Repository</h3>
#       <p>1. Copy the URL from the green <strong>Code</strong> button on the repo page.</p>
#       <p>2. Open your terminal/command prompt and run:</p>
#       <pre><code>git clone <REPO_URL>
# cd <REPO_NAME>
# code .</code></pre>
#       <p>This downloads the code and opens it directly in VS Code.</p>
#     </div>
#     <!-- Update Repo -->
#     <div class="card orange">
#       <h3>Step 3: How to Update?</h3>
#       <p>If we add new lessons or fix bugs, you don't need to re-download everything. Just run:</p>
#       <pre><code>git pull origin main</code></pre>
#       <p>This instantly updates your local files to match the latest version.</p>
#     </div>
#   </div>
# </div>
