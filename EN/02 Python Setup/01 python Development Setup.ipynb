# %% [markdown]
# <style>
#   /* Global Settings */
#   * { box-sizing: border-box; }
#
#   /* Section Card Style */
#   .section-card {
#     background: linear-gradient(145deg, rgb(61, 61, 87), rgb(49, 49, 70));
#     border-radius: 15px; padding: 2rem; margin: 0 auto 2.5rem;
#     box-shadow: 0 8px 20px rgba(0, 0, 0, 0.5); width: 100%; max-width: 95vw;
#   }
#
#   /* Typography */
#   h1 { text-align: center; color: #ffffff; font-size: 2.5rem; margin-bottom: 1.5rem; font-family: 'Poppins', sans-serif; letter-spacing: 1px; }
#   .container > .card:last-child {
#       margin-bottom: 2rem;
#     }
#   .section-card h2 { text-align: center; color: #ffffff; font-size: 1.8rem; margin-bottom: 1.5rem; font-family: 'Poppins', sans-serif; letter-spacing: 1px; }
#   .card h3 { color: #ffffff; font-size: 1.3rem; margin-bottom: 0.75rem; font-weight: bold; font-family: 'Segoe UI', sans-serif; }
#
#   p, li { color: #dcdcdc; font-size: 0.95rem; line-height: 1.6; font-family: 'Segoe UI', sans-serif; margin-bottom: 0.5rem; }
#   ul, ol { padding-left: 1.25rem; margin-bottom: 0.75rem; }
#   code { background: rgba(0,0,0,0.3); padding: 2px 6px; border-radius: 4px; color: #ffab40; font-family: monospace; font-size: 0.9rem; }
#   pre { background: #1a1a2e; padding: 1rem; border-radius: 8px; overflow-x: auto; margin-top: 10px; }
#
#   /* Inner Cards */
#   .container { display: flex; flex-direction: column; gap: 1.25rem; }
#   .card {
#     background: linear-gradient(145deg, #24243e, #1e1e3a);
#     border-radius: 12px; padding: 1.5rem; margin: 0 auto; width: 90vw;
#     box-shadow: 0 6px 16px rgba(0, 0, 0, 0.4); transition: transform 0.3s ease, box-shadow 0.3s ease;
#     border-left: 4px solid transparent;
#   }
#   .card:hover { transform: translateY(-5px); box-shadow: 0 10px 20px rgba(0, 0, 0, 0.5); }
#
#   /* Images */
#   img { display: block; max-width: 80%; height: auto; margin: 20px auto; border-radius: 8px; border: 1px solid rgba(255,255,255,0.1); }
#
#   /* Note */
#   .note { background: #fdd835; color: #000; padding: 1rem; border-radius: 6px; margin-top: 1rem; font-style: italic; }
#
#   /* TOC */
#   .toc-card ul { list-style-type: none; padding-left: 0; }
#   .toc-card ul li a { color: #29b6f6; text-decoration: none; transition: color 0.3s ease; }
#   .toc-card ul li a:hover { color: #66bb6a; text-decoration: underline; }
#
#   /* Colors */
#   .blue { border-left-color: #29b6f6; }
#   .green { border-left-color: #66bb6a; }
#   .orange { border-left-color: #ffa726; }
#   .purple { border-left-color: #ba68c8; }
#   .red { border-left-color: #ef5350; }
#
#   @media (max-width: 768px) {
#     .section-card { padding: 1.25rem; }
#     h1 { font-size: 2rem; }
#     .card { padding: 1rem; width: 100%; }
#   }
# </style>
#
# <div class="section-card">
#   <h1>Python Development Setup</h1>
# </div>
#
# <div class="section-card" id="toc0_">
#   <h2>Table of Contents</h2>
#   <div class="container">
#     <div class="card blue toc-card">
#       <h3>Contents</h3>
#       <ul>
#         <li><a href="#toc1_">1. Python Environment</a></li>
#         <li><a href="#toc2_">2. VS Code (The Editor)</a></li>
#         <li><a href="#toc3_">3. Jupyter Notebook (Interactive Lab)</a></li>
#         <li><a href="#toc4_">4. Conda & venv (Environment Managers)</a></li>
#         <li><a href="#toc5_">5. Why this Setup?</a></li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc1_">
#   <h2>1. Python Development Environment</h2>
#   <div class="container">
#     <div class="card orange">
#       <h3>What is it?</h3>
#       <p>It's your digital workspace—a collection of tools (IDEs, compilers, and managers) that work together to help you write, test, and run Python code efficiently.</p>
#       <img src="../../images/IDES.png" alt="Env" style="max-width: 60%; display: block; margin: 15px auto; border-radius: 8px;">
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc2_">
#   <h2>2. VS Code (Visual Studio Code)</h2>
#   <div class="container">
#     <div class="card purple">
#       <h3>The "Swiss Army Knife" of Editors</h3>
#       <p>A lightweight but powerful code editor by Microsoft. It's the industry standard thanks to features like:</p>
#       <ul>
#         <li><strong>IntelliSense:</strong> Smart code completion.</li>
#         <li><strong>Extensions:</strong> Thousands of plugins for Python and UI.</li>
#         <li><strong>Integrated Terminal:</strong> Run code without leaving the editor.</li>
#       </ul>
#       <img src="../../images/python-vscode.png" alt="VS Code" style="max-width: 60%; display: block; margin: 15px auto; border-radius: 8px;">
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc3_">
#   <h2>3. Jupyter Notebook</h2>
#   <div class="container">
#     <div class="card red">
#       <h3>The Interactive Laboratory</h3>
#       <p>Perfect for learning and data science. It allows you to mix <strong>live code</strong>, <strong>rich text</strong>, and <strong>visualizations</strong> in one document.</p>
#       <p>In this course, we use the Jupyter extension inside VS Code for the best of both worlds.</p>
#       <img src="../../images/jupyter-interface.png" alt="Jupyter" style="max-width: 60%; display: block; margin: 15px auto; border-radius: 8px;">
#     <div class="note">
#       <strong>Tip:</strong> Jupyter is best for prototyping and step-by-step learning!
#     </div>
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc4_">
#   <h2>4. Environment Management</h2>
#   <div class="container">
#     <div class="card green">
#       <h3>Keep Projects Isolated</h3>
#       <p>To avoid conflicts between different projects, we use isolated environments:</p>
#       <ul>
#         <li><strong>Conda:</strong> Powerful manager for Data Science and complex dependencies.</li>
#         <li><strong>venv:</strong> Python's built-in, lightweight environment creator.</li>
#       </ul>
#       <img src="../../images/venv_vs_conda.png" alt="Conda" style="max-width: 60%; display: block; margin: 15px auto; border-radius: 8px;">
#     </div>
#   </div>
# </div>
#
# <div class="section-card" id="toc5_">
#   <h2>5. Why this Modern Setup?</h2>
#   <div class="container">
#     <div class="card blue">
#       <ul>
#         <li><strong>Productivity:</strong> Debug and run code faster with VS Code.</li>
#         <li><strong>Consistency:</strong> Conda/venv ensure your code runs the same on any machine.</li>
#         <li><strong>Clarity:</strong> Jupyter makes complex logic easy to follow and visualize.</li>
#       </ul>
#     </div>
#   </div>
# </div>
